# %%
import pandas as pd
import numpy as np
import pickle as pkl
import matplotlib.pyplot as plt

from nltk import word_tokenize 
from nltk.util import ngrams
from nltk.corpus import stopwords
from tqdm.notebook import tqdm_notebook as tqdm

from sklearn.feature_extraction.text import CountVectorizer

# %%
import stanza
#stanza.download('en')
nlp = stanza.Pipeline('en')
# Out:
# 2020-08-14 14:38:50 INFO: Loading these models for language: en (English):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | ewt       |
# | pos       | ewt       |
# | lemma     | ewt       |
# | depparse  | ewt       |
# | sentiment | sstplus   |
# | ner       | ontonotes |
# =========================
#
# 2020-08-14 14:38:50 INFO: Use device: cpu
# 2020-08-14 14:38:50 INFO: Loading: tokenize
# 2020-08-14 14:38:50 INFO: Loading: pos
# 2020-08-14 14:38:51 INFO: Loading: lemma
# 2020-08-14 14:38:51 INFO: Loading: depparse
# 2020-08-14 14:38:53 INFO: Loading: sentiment
# 2020-08-14 14:38:54 INFO: Loading: ner
# 2020-08-14 14:38:55 INFO: Done loading processors!

# %%
# read in the HT data file (change according to the dataset). 
# Same process for feature extraction will follow for any dataset. 
# Refer to the paper for the feature extraction part

data_file = "../Data/ComplexDataLab_Canadian_OctoberBatch.csv"
data = pd.read_csv(data_file, index_col=0)
data.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:3051: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                 PostingDate  \
# 0  Thu 14 Apr 2016 11:40 AM
# 1  Tue 04 Jul 2017 08:30 AM
# 2  Mon 03 Jul 2017 07:04 AM
# 3  Thu 29 Sep 2016 12:06 AM
# 4  Tue 03 May 2016 06:16 PM
#
#                                                  Url l_Location u_Age  \
# 0  https://independent.com.calgary.listcrawler.co...    calgary    31
# 1  https://yolo.com.calgary.listcrawler.com/post/...    calgary    28
# 2  https://milfy.com.toronto.listcrawler.com/post...    toronto    34
# 3  https://max80.com.vancouver.listcrawler.com/po...  vancouver    25
# 4  https://milfy.com.barrie.listcrawler.com/post/...     barrie    33
#
#                                        u_Description  \
# 0  Take the time to enjoy your night with me.. 40...
# 1  Maria Vega  Latina for Real!!!Plz read my rate...
# 2  Sexual Deviant LOVES 2ROCK IT NAUGHTY! My sexu...
# 3  778 8four6 4234 Hi! I'm Tiffany baby! ;) LETS ...
# 4  HI GUYS ! I CANT WAIT TO MEET YOU !  I AM 33 5...
#
#                                              u_Title  \
# 0                                     Sinfully sweet
# 1  Tired fake AddsFake Expectations36 DDD Real 10...
# 2  New Halton Girl! Outcall MIND BL0-WING DEVIANT...
# 3   Early Morning Drop In! Rates  $40-$100 TEXT NOW!
# 4  BARBIE aka (Cheyenne) 33 fetishes welcome, soa...
#
#                                           u_Location  e_PhoneNumbers  \
# 0  Calgary, Downtown, Mins from Downtown, Northea...  ['4039715391']
# 1  Calgary, Downtown, DOWNTOWN CORE INCALL and OU...  ['4389267478']
# 2  Burlington, Hamilton, Oakville milton, Oakvill...  ['2897801427']
# 3  City of Vancouver, MARINE &amp; CAMBIE, Vancouver              []
# 4               Barrie, Barrie and surrounding areas  ['7053314617']
#
#    u_PhoneNumbers e_Emails
# 0  ['4039715391']       []
# 1  ['4389267478']       []
# 2  ['2897801427']       []
# 3  ['7788464234']       []
# 4  ['7053314617']       []

# %%
# size of the data
data.shape
# Out:
# (932888, 10)

# %%
data = data.drop_duplicates()
data.shape
# Out:
# (932888, 10)

# %%
# randomly sample some data points 
sampled_data = data.sample(n=5000)

# %%
sampled_data.head()
# Out:
#                      PostingDate  \
# 642087  Fri 18 Aug 2017 08:33 PM
# 575134  Fri 02 Jun 2017 12:25 AM
# 570482  Wed 16 Mar 2016 03:09 PM
# 801067  Sat 16 Feb 2019 03:33 AM
# 33314   Wed 14 Jun 2017 05:27 PM
#
#                                                       Url l_Location u_Age  \
# 642087  https://candy.com.montreal.listcrawler.com/pos...   montreal    21
# 575134  https://candy.com.brantford.listcrawler.com/po...  brantford    32
# 570482  https://candy.com.toronto.listcrawler.com/post...    toronto    21
# 801067  https://blackdynomite.com.toronto.listcrawler....    toronto    21
# 33314   https://aypapi.com.vancouver.listcrawler.com/p...  vancouver    22
#
#                                             u_Description  \
# 642087  Hi boys :)  Lexie21 years old, 5'6 125lbs Blon...
# 575134  Brittney JUICY VOLUPTUOUS % all CANADIAN CUTIE...
# 570482  your dream girl is here! I'm Ms StacyThis is a...
# 801067  hi gentlemen  My name is destiny ’m new in INT...
# 33314   Hey gentlemen!< A Lets have some fun .. I'm a ...
#
#                                                   u_Title  \
# 642087         Lexie  ---    438-800-9850100% Independant
# 575134  Coming to Town tomorrow BOOK NOW   SEXY CURVY ...
# 570482                      VB  B   P #1M$TD 647-713-9111
# 801067          Come taste the sweetest caramel chocolate
# 33314   the perfect treat       you haven't had  the b...
#
#                                                u_Location  e_PhoneNumbers  \
# 642087                         City of Montreal, Montreal  ['4388009850']
# 575134                     Brantford-Woodstock, Woodstock  ['2898316607']
# 570482  427/Dundas, Brampton, City of Toronto, Mississ...  ['6477139111']
# 801067                                        Mississauga  ['4167192068']
# 33314                        Airport, Richmond, Vancouver  ['6477999487']
#
#         u_PhoneNumbers e_Emails
# 642087  ['4388009850']       []
# 575134  ['2898316607']       []
# 570482  ['6477139111']       []
# 801067  ['6477192068']       []
# 33314   ['6477999487']       []

# %%
data['label'] = None
data['group'] = None
grp_id = 1
for grp in tqdm(data.groupby('u_PhoneNumbers')):
    ids = grp[1].index.values
    if len(ids) <= 1:
        data['label'].iloc[ids] = 0
    else:
        data['label'].iloc[ids] = 1
    data['group'].iloc[ids] = grp_id
    grp_id += 1
# Out:
# HBox(children=(FloatProgress(value=0.0, max=86756.0), HTML(value='')))

# %%
data.head()
# Out:
#                 PostingDate  \
# 0  Thu 14 Apr 2016 11:40 AM
# 1  Tue 04 Jul 2017 08:30 AM
# 2  Mon 03 Jul 2017 07:04 AM
# 3  Thu 29 Sep 2016 12:06 AM
# 4  Tue 03 May 2016 06:16 PM
#
#                                                  Url l_Location u_Age  \
# 0  https://independent.com.calgary.listcrawler.co...    calgary    31
# 1  https://yolo.com.calgary.listcrawler.com/post/...    calgary    28
# 2  https://milfy.com.toronto.listcrawler.com/post...    toronto    34
# 3  https://max80.com.vancouver.listcrawler.com/po...  vancouver    25
# 4  https://milfy.com.barrie.listcrawler.com/post/...     barrie    33
#
#                                        u_Description  \
# 0  Take the time to enjoy your night with me.. 40...
# 1  Maria Vega  Latina for Real!!!Plz read my rate...
# 2  Sexual Deviant LOVES 2ROCK IT NAUGHTY! My sexu...
# 3  778 8four6 4234 Hi! I'm Tiffany baby! ;) LETS ...
# 4  HI GUYS ! I CANT WAIT TO MEET YOU !  I AM 33 5...
#
#                                              u_Title  \
# 0                                     Sinfully sweet
# 1  Tired fake AddsFake Expectations36 DDD Real 10...
# 2  New Halton Girl! Outcall MIND BL0-WING DEVIANT...
# 3   Early Morning Drop In! Rates  $40-$100 TEXT NOW!
# 4  BARBIE aka (Cheyenne) 33 fetishes welcome, soa...
#
#                                           u_Location  e_PhoneNumbers  \
# 0  Calgary, Downtown, Mins from Downtown, Northea...  ['4039715391']
# 1  Calgary, Downtown, DOWNTOWN CORE INCALL and OU...  ['4389267478']
# 2  Burlington, Hamilton, Oakville milton, Oakvill...  ['2897801427']
# 3  City of Vancouver, MARINE &amp; CAMBIE, Vancouver              []
# 4               Barrie, Barrie and surrounding areas  ['7053314617']
#
#    u_PhoneNumbers e_Emails label  group
# 0  ['4039715391']       []     1  23710
# 1  ['4389267478']       []     1  31764
# 2  ['2897801427']       []     1  16253
# 3  ['7788464234']       []     1  80398
# 4  ['7053314617']       []     1  75746

# %%
#data.to_csv("data_with_labels.csv",index=None)
data = pd.read_csv("data_with_labels.csv")
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:3051: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
ad_texts = data.u_Description.values
ad_titles = data.u_Title.values

# %%
counter = 0
for ad in tqdm(ad_texts):
    ents = nlp(ad.lower()).entities
    for entity in ents:
        #print(type(entity))
        if entity.type == 'PERSON':
            print(ad, entity)
            counter += 1
# Out:
# HBox(children=(FloatProgress(value=0.0, max=932888.0), HTML(value='')))
# Hello Gentlemen  Nikki Jade here in ORILLIA, to cater to your every desire... Just ask! Let me spoil you with my natural talents, my refined skills, & my warm welcoming personality  Independent INCALLS ONLY ORILLIA NO BBFSNO blocked/APP #'s GRK friendly 30+ minutes notice please! FaceTime sessionsE-transfers TEXT ONLY: (647)-524-2764 {
#   "text": "nikki",
#   "type": "PERSON",
#   "start_char": 17,
#   "end_char": 22
# }
# Drop Dead Gorgeous treat  A MUST SEE 4 those who desire a Naughty Skilled Playful Girl No black guys No Exceptions(647)499-3482 Amanda {
#   "text": "amanda",
#   "type": "PERSON",
#   "start_char": 128,
#   "end_char": 134
# }
# Shannon Is now available for your Saturday night. Known to have the city's best BG service, Shannon also provides quality, unrushed adult play and has a simple menu for  you to explore.  34 yr.  old redhead with blue eyes and a fair skin. 38-34-38, 5'9, BBW with DD's text preferred 905-531-8764905-531-8764 {
#   "text": "shannon",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 7
# }
# I'm Mandy, 22 yr-old BUSTY, BEAUTIFUL & SEXY.  I just arrived this Spring, brings you a very special treat from SINGAPORE. I am the perfect companion.  I am 35E-24-35, Sweet & ALL NATURAL body 5'4 tall with 110lbs, amazing butt.  My New Roommate Karen is Ready for fun too! Anything OK & Never Rush!  IN/OUT $60 LINGERIE STOCKING HIGH HEELS Located @ Finch/Victoria Park, SCARBOROUGH. Short Stay Only! 2_TIMES_SPECIAL!  call/txt: 647-939-3208 ONLY $60/hh incall {
#   "text": "karen",
#   "type": "PERSON",
#   "start_char": 246,
#   "end_char": 251
# }
# Hi guys!!! Super Hot Asian Models Available!! Taiwanese CoCo, Busty & Sexy! Only Available for short Term only You call to me when you get hereSingapor Cindy!! Never Rush & OpenMinded!!! Stockings High Heels Sexy Lingerie Role Play & More!! Guarantee A+ services!Your Satisfaction is my Goal 24/7 Call/Txt: 416-558-9601 {
#   "text": "cindy",
#   "type": "PERSON",
#   "start_char": 152,
#   "end_char": 157
# }
# Hi I am Nikki  Nordisch Easy going and I love  to be fit ! Text or call (705) 345-08165'2 108 pounds {
#   "text": "nikki  nordisch",
#   "type": "PERSON",
#   "start_char": 8,
#   "end_char": 23
# }
# Hi I’m SARAH! Freaky, slim, one of a kind beauty! +1 587-333-3444 Don’t miss your chance for an unforgettable night with me {
#   "text": "sarah",
#   "type": "PERSON",
#   "start_char": 7,
#   "end_char": 12
# }
# Hello Gentlemen of St John's My name is Bianca Jaguar, Mature Sensual, Youthful over 50 French Canadian from Montreal! I will be visiting St John's November 18-22. Visit my website for more information and extended dates. Pre booking is strongly advised.  514-825-9248 400/h, I'm 5'6, 138lbs,athletic build,36/28/36, blond hair, blue eyes! biancajaguar.com {
#   "text": "st john's",
#   "type": "PERSON",
#   "start_char": 19,
#   "end_char": 28
# }
# Rachel is my NAME  Catering to MATURE and RESPECTFUL MENThis young ebony provider is polished & nice Discrete/Drama Free Available 24Hours My sessions are nothing like the rest.What you See is What YOU Get I'm playful, energetic,and Sweet. (Imagine the fun we will have) Sexy with an amazingly soft bubble booty  Waiting for your call (925)399-8735 I am 100% independent I look FORWARD to being your companion   Clean, Private, & Friendly  100% NO DRAMA!!!  100% NO GAMES!!!  100% INDEPENDENT!  100% SAFE {
#   "text": "rachel",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 6
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-392ea1fea51c> in <module>
#       1 counter = 0
#       2 for ad in tqdm(ad_texts):
# ----> 3     ents = nlp(ad.lower()).entities
#       4     for entity in ents:
#       5         #print(type(entity))
#
# /usr/local/lib/python3.6/dist-packages/stanza/pipeline/core.py in __call__(self, doc)
#     164         assert any([isinstance(doc, str), isinstance(doc, list),
#     165                     isinstance(doc, Document)]), 'input should be either str, list or Document'
# --> 166         doc = self.process(doc)
#     167         return doc
#     168
#
# /usr/local/lib/python3.6/dist-packages/stanza/pipeline/core.py in process(self, doc)
#     158         for processor_name in PIPELINE_NAMES:
#     159             if self.processors.get(processor_name):
# --> 160                 doc = self.processors[processor_name].process(doc)
#     161         return doc
#     162
#
# /usr/local/lib/python3.6/dist-packages/stanza/pipeline/ner_processor.py in process(self, document)
#      32         preds = []
#      33         for i, b in enumerate(batch):
# ---> 34             preds += self.trainer.predict(b)
#      35         batch.doc.set([doc.NER], [y for x in preds for y in x], to_token=True)
#      36         # collect entities into document attribute
#
# /usr/local/lib/python3.6/dist-packages/stanza/models/ner/trainer.py in predict(self, batch, unsort)
#      76         self.model.eval()
#      77         batch_size = word.size(0)
# ---> 78         _, logits, trans = self.model(word, word_mask, wordchars, wordchars_mask, tags, word_orig_idx, sentlens, wordlens, chars, charoffsets, charlens, char_orig_idx)
#      79
#      80         # decode
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/stanza/models/ner/model.py in forward(self, word, word_mask, wordchars, wordchars_mask, tags, word_orig_idx, sentlens, wordlens, chars, charoffsets, charlens, char_orig_idx)
#      93         if self.args['char'] and self.args['char_emb_dim'] > 0:
#      94             if self.args.get('charlm', None):
# ---> 95                 char_reps_forward = self.charmodel_forward.get_representation(chars[0], charoffsets[0], charlens, char_orig_idx)
#      96                 char_reps_forward = PackedSequence(char_reps_forward.data, char_reps_forward.batch_sizes)
#      97                 char_reps_backward = self.charmodel_backward.get_representation(chars[1], charoffsets[1], charlens, char_orig_idx)
#
# /usr/local/lib/python3.6/dist-packages/stanza/models/common/char_model.py in get_representation(self, chars, charoffsets, charlens, char_orig_idx)
#      97     def get_representation(self, chars, charoffsets, charlens, char_orig_idx):
#      98         with torch.no_grad():
# ---> 99             output, _, _ = self.forward(chars, charlens)
#     100             res = [output[i, offsets] for i, offsets in enumerate(charoffsets)]
#     101             res = unsort(res, char_orig_idx)
#
# /usr/local/lib/python3.6/dist-packages/stanza/models/common/char_model.py in forward(self, chars, charlens, hidden)
#      90             hidden = (self.charlstm_h_init.expand(self.args['char_num_layers'], batch_size, self.args['char_hidden_dim']).contiguous(),
#      91                       self.charlstm_c_init.expand(self.args['char_num_layers'], batch_size, self.args['char_hidden_dim']).contiguous())
# ---> 92         output, hidden = self.charlstm(embs, charlens, hx=hidden)
#      93         output = self.dropout(pad_packed_sequence(output, batch_first=True)[0])
#      94         decoded = self.decoder(output)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/stanza/models/common/packed_lstm.py in forward(self, input, lengths, hx)
#      20             input = pack_padded_sequence(input, lengths, batch_first=self.batch_first)
#      21
# ---> 22         res = self.lstm(input, hx)
#      23         if self.pad:
#      24             res = (pad_packed_sequence(res[0], batch_first=self.batch_first)[0], res[1])
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     560         else:
#     561             result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
# --> 562                               self.num_layers, self.dropout, self.training, self.bidirectional)
#     563         output = result[0]
#     564         hidden = result[1:]
#
# KeyboardInterrupt:

# %%
counter
# Out:
# 9

# %%
c = 0
for ad in tqdm(ad_texts):
    ents = nlp(ad).entities
    for entity in ents:
        #print(type(entity))
        if entity.type == 'PERSON':
            print(ad, entity)
            c += 1
# Out:
# HBox(children=(FloatProgress(value=0.0, max=932888.0), HTML(value='')))
# Maria Vega  Latina for Real!!!Plz read my rates, no negotiationsBlocked Calls,Thugs,Pimps,No Time Wasters  Sexy and Real Companionship,Fetish FreindlyReal services will be delivered Very well CAF reviewed  Come see what others can't deliver but always promise  438-926-7478Etranfer & My Incall Downtown SW  Rates 120$ 15 mins /160$ 30 mins/200$ 45 mins /260$ 60 mins Outcalls All Calgary 300$ 60 mins  Extras availablesStop wasting your With Fake pics,Fake promises {
#   "text": "Maria Vega",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 10
# }
# Maria Vega  Latina for Real!!!Plz read my rates, no negotiationsBlocked Calls,Thugs,Pimps,No Time Wasters  Sexy and Real Companionship,Fetish FreindlyReal services will be delivered Very well CAF reviewed  Come see what others can't deliver but always promise  438-926-7478Etranfer & My Incall Downtown SW  Rates 120$ 15 mins /160$ 30 mins/200$ 45 mins /260$ 60 mins Outcalls All Calgary 300$ 60 mins  Extras availablesStop wasting your With Fake pics,Fake promises {
#   "text": "Pimps",
#   "type": "PERSON",
#   "start_char": 84,
#   "end_char": 89
# }
# Maria Vega  Latina for Real!!!Plz read my rates, no negotiationsBlocked Calls,Thugs,Pimps,No Time Wasters  Sexy and Real Companionship,Fetish FreindlyReal services will be delivered Very well CAF reviewed  Come see what others can't deliver but always promise  438-926-7478Etranfer & My Incall Downtown SW  Rates 120$ 15 mins /160$ 30 mins/200$ 45 mins /260$ 60 mins Outcalls All Calgary 300$ 60 mins  Extras availablesStop wasting your With Fake pics,Fake promises {
#   "text": "Freindly",
#   "type": "PERSON",
#   "start_char": 142,
#   "end_char": 150
# }
# Sexual Deviant LOVES 2ROCK IT NAUGHTY! My sexual exploits are unforgettable &guaranteed 2 surprise &amaze you! keep tellin' em Im like a drug 1 hit &you're hooked lol come have a taste of me, see if you can have just 1? Love 2 please &satisfy my man! I love the scenario & 2 be purchased &used! I've never left a man unsatisfied! So how can I be your high tonight baby? No blocked callers  Text Sass N AssMama Skitlz 289-780-1427 Thx see you soon {
#   "text": "Sexual Deviant",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 14
# }
# 778 8four6 4234 Hi! I'm Tiffany baby! ;) LETS PLAY!! ******************************* TERMINALLY PRETTY 130lbs * 5'7 * 24yrs * 34C A REAL SEXY STUNNER! ******************************* INCALL RATES: $40 - covered hed $60 - bare hed $80 - hed + seks $100 - mutual 4play + seks ******************************* TIFFANY xoxxx 7seven8 84six 42three4 {
#   "text": "Tiffany",
#   "type": "PERSON",
#   "start_char": 24,
#   "end_char": 31
# }
# HI GENTLEMEN:Welcome to my private-discrete encounter by TANIA I am looking for a self-directed GENTLEMEN arrangement.  I am a beautifull, single, independent play-mate that can make your day stress free. Cetral ACFor appointments please call me at 647 784 8774PLEASE NO BLOCKED CALLS OR TEXTS {
#   "text": "Cetral ACFor",
#   "type": "PERSON",
#   "start_char": 205,
#   "end_char": 217
# }
# Call Now 587-776-2822 Looking for some companionship & a good time? I'm the girl you need so let's meet & have some fun! Very professional & discreet  You will be satisfied  Private Place Incall    Clean & Classy   Discreet & Drama free  [] PROVIDER  587-776-2822 Khloe {
#   "text": "Khloe",
#   "type": "PERSON",
#   "start_char": 264,
#   "end_char": 269
# }
# I'm Priya, a stunning Spanish, Indian & White, Canadian beauty. Fluent in English. I'm a sweet, openminded, girl looking to meet generous cuties! Gentlemen I've been fortunate enough to encounter, describe me as sexy, openminded, kinky, memorable & more.. Top notch service 5'4"  140LBS  36C INCALLS by appointment. 647-485-2374 I do not see black men {
#   "text": "Priya",
#   "type": "PERSON",
#   "start_char": 4,
#   "end_char": 9
# }
# New beautiful Asian girl just came to town! My name is Rose, 21 yrs old, 5'3", 106 lbs, 36D BUSTY BODY! Gentle hand Slender Legs Soft Body And Smooth Skin. Friendly Attitude And Very Satisfactory Services. 100% Real Hot Girl GUARANTEE!  438-793-8022  Incall & Outcall {
#   "text": "Rose",
#   "type": "PERSON",
#   "start_char": 55,
#   "end_char": 59
# }
# Hello my name is Nikki 35 years old  Hazel eyes and short brown hair I'm 5'6", tight and very pretty  I love my job and to have fun  Very  and w*t  I offer a lot of services including massages Clean and cute Discrete and independent  SERIOUS MEN ONLY ***very safe*** OUTCALL Special Let me be your new attraction text me 613-777-8181 {
#   "text": "Nikki",
#   "type": "PERSON",
#   "start_char": 17,
#   "end_char": 22
# }
# Hello my name is Nikki 35 years old  Hazel eyes and short brown hair I'm 5'6", tight and very pretty  I love my job and to have fun  Very  and w*t  I offer a lot of services including massages Clean and cute Discrete and independent  SERIOUS MEN ONLY ***very safe*** OUTCALL Special Let me be your new attraction text me 613-777-8181 {
#   "text": "Hazel",
#   "type": "PERSON",
#   "start_char": 37,
#   "end_char": 42
# }
# New Horny Russian Beauties $30 special Hey, I am  Nicole and new in town. :)  I am promise maximum pleasure to a nice gentleman   Sexy, Classy, Russian ladies.  No texts please. It is a landline. Just call me honey: 647-878-8056    Guelph /Breslau/ {
#   "text": "Nicole",
#   "type": "PERSON",
#   "start_char": 50,
#   "end_char": 56
# }
# Hi gentlemen's I am Mariana, a mature independent escort  and exclusive travel companion. I offer a discreet & personal  intimate companionship experience for respectful gentlemen's. Non-rushed fun filled time spent with me 100% drama free Safe, clean & discreet Open minded No blocked calls   No black gents  5'1  120 pounds  txt & call NOW  647-495-1178 {
#   "text": "Mariana",
#   "type": "PERSON",
#   "start_char": 20,
#   "end_char": 27
# }
# Hey babe , I'm Mandy Always discreet , clean & a good personality   My goal is to make you comfortable & I promise you will enjoy your time with me   NEW!  Tight & just right   Not rushed, take your time   SORRY BUT NO BLACK MEN AVAILIBLE NOW !   Call or text me babe   @  Hope to hear from you soon  Text or call Mandy2262458283 {
#   "text": "Mandy",
#   "type": "PERSON",
#   "start_char": 15,
#   "end_char": 20
# }
# Hey Guys  Despite what they might have you believe, I have found that there can bepassion without love, desire without familiarity, and satisfaction without commitment. It's Sasha, back by popular demand!  I am your #1 BBW and always eager to please.  I am 5ft5, 250lbs 40DD Unforgettable curves, mesmerizing blue eyes  and a smile that will sweep you off your feet  Call/ Text 647-290-0535 No Private Callers  No Black Gents Under 40  No Pic Messaging {
#   "text": "Sasha",
#   "type": "PERSON",
#   "start_char": 174,
#   "end_char": 179
# }
# ARE YOU READY TO HAVE THE BEST TIME OF YOUR LIFE ???Let US Cater 2 you & Provide 5 Experience you deserve. Sexy, Addictive & Always Ready For Kinky Fun!Tired of Fake Boring GirlsFrom the Moment we meet, you will be the CENTER OF OUR ATTENTION!Super Naughty Exactly What YouHave Been Searching (289) 813-2909LIMITED TIMENew In Town Skills of a Stars! This is NOT a agency just Friends working together Srious Gntmn ony {
#   "text": "Srious Gntmn",
#   "type": "PERSON",
#   "start_char": 401,
#   "end_char": 413
# }
# Hey guys, I'm Britney. I'm a super thick, curvy girl  ready for some fun.  I can satisfy all your needs.  Always fresh n clean.  With a mo**uth that can please.  Thick girls do it better!!!  Couples welcome! Text only 226-499-9164 {
#   "text": "Britney",
#   "type": "PERSON",
#   "start_char": 14,
#   "end_char": 21
# }
# Hey, I'm Mallory the ultimate good time girl!! In Midland area,! This girl loves to have fun,making ypur dreams reality so let's keep the party going all night long naughty or nice, you decide!!I want to play with you!!! Come see me or I can come to you!! Let me put a smile on your face today!!  professional, clean, not just a call will give you an experience and make your fantasy reality.705-241-5068 ask about after midnight specials!!!!@!   Don't forget to ask about Duos! Double the fun!!! $50 off hour duo booking {
#   "text": "Mallory",
#   "type": "PERSON",
#   "start_char": 9,
#   "end_char": 16
# }
# Hey, I'm Mallory the ultimate good time girl!! In Midland area,! This girl loves to have fun,making ypur dreams reality so let's keep the party going all night long naughty or nice, you decide!!I want to play with you!!! Come see me or I can come to you!! Let me put a smile on your face today!!  professional, clean, not just a call will give you an experience and make your fantasy reality.705-241-5068 ask about after midnight specials!!!!@!   Don't forget to ask about Duos! Double the fun!!! $50 off hour duo booking {
#   "text": "Duos",
#   "type": "PERSON",
#   "start_char": 473,
#   "end_char": 477
# }
# Hi gentleman . I'm Angelica, a THICK chocolate vixen. I'm sensual,sweet,and addictive! STOP wasting your time and experience ultimate pleasure. 925.375.7590 {
#   "text": "Angelica",
#   "type": "PERSON",
#   "start_char": 19,
#   "end_char": 27
# }
# Hey gentlemen , I am a passionate playmate that prides myself in providing amazing service. A natural beauty & equipped with great Skills. I'm an exciting little ball of fire, sweet yet feisty. Time well spent :One session with me will leave you breathless and refreshed wanting more of me. 100% REAL accurate picture  Independent 100% Clean & DiscreetSerious Clients Only! Brianna 587-774-1404 No Black {
#   "text": "Brianna",
#   "type": "PERSON",
#   "start_char": 374,
#   "end_char": 381
# }
# 💋💋Hey guys.....  I'am 24 years Beautiful Naughty American Girl, Very H0t &  Sexy💋💋i have a Clean & s0ft Pussy🍩i am a classy latina w0man with a  beautiful face and a s0ft curvy b0dy y0u will find t0 be quite addicting🍩  😘⎷N0w i'm l00king f0r a sex partner & wh0 can fuck me difficult & satisfy me  f0r a man t0 spend time  💝CI l0ve t0 suck & sex, I have a great experience?My Pussy Cute & Clean, My  Wet Pussy Y0u can suck 💝⎞⎛ Really I'm Enj0ying The M0ment💝⎞⎛  🍓y0ur age....is n0t matter f0r me 💝⎞⎛I'm Available 24 h0urs?Never rushed u  will enj0y the m0st relaxing and unf0rgettable experience in y0ur life  ☎☎ Just call or text now☎☎304_832_1343☎☎  🍓(PLEASE D0N’T CALL ME ) 🍓  After ur reply i will tell u & give u m0re naked pics.  Available & Ready N0w! N0 WAIT N0 RUSH🍓🍓🍓🍓.  🔴🍀Best Bl0wj0b🍀PLAY IN MY PRIVATE BED R00M🔴🍀 Best Kisser  🔴🍀Best Time with Me🔴🍀 Free Sh0wer  🔴🍀Specially Fuck y0ur 0wn style, D0ggy, Anal, 0ral,69 0r Any 0ther Style  🔴🍀Full Service Sex (Sex with0ut C0nd0m)  🔴🍀Girlfriend Experience  🍓🍓Y0u Can Eat Me. Kiss Me Everywhere.  🚗🚗0UT CALL IN Y0UR CITY, INCALL MY H0ME>H0TEL>CAR>0R ANYWHERE Y0U Like🚗🚗  🔴🔴N0 DRAMA?????????? N0 RUSH 🔴🔴  Really H0rney and very seri0us. I am free all day and night let's d0 this.  C0me 0n in my r00m 0r Anywhere y0u like....  ☎☎If Y0u Interested And Wanna Meet With Me Then Text Me I am 0nline n0w: :  ☎☎ Just text now☎☎ 304_832_1343 ☎☎ {
#   "text": "Best Kisser",
#   "type": "PERSON",
#   "start_char": 826,
#   "end_char": 837
# }
# Upscale Professional & DiscreetTotally Satisfying & Absolutely Addictive!(T R D)       dpure majic mouth skills S, Ac, &    !  reasonable  & Dc&   TotaL cgSLLS SLLS SLLS     Just ask for Shayla TXT 226-312-2361 80hh/150hr 60-15mins,safe play,no a*nl,no bb, discrete brantford apartment Remember the name is Shayla!! {
#   "text": "Shayla",
#   "type": "PERSON",
#   "start_char": 307,
#   "end_char": 313
# }
# Resplendent femme fatale in lingerie. You deserve this. Respectful, well-groomed gents welcome. $150/hh $200/hr $300/1.5hrs Pre-booking recommended. Daily 10am - 10pm. Bookings not accepted past 9pm (last appt). Private condo Last day is Jan 31st. Twitter: @KatevKatz 613-204-3368 TEXT ONLY {
#   "text": "@KatevKatz",
#   "type": "PERSON",
#   "start_char": 257,
#   "end_char": 267
# }
# Hi gents I'm Lexi love  I am a well reviewed, quality over quantity, safe provider offering you unique experiences that will leave you feeling satisfied and very relieved. I take pride in being well dressed and well groomed at all times and appreciate a gentleman that can do the same.  Unrushed & Unforgettable You are gonna love me! please call to set up a session you wont soon forget.        403-402-4485 {
#   "text": "Lexi",
#   "type": "PERSON",
#   "start_char": 13,
#   "end_char": 17
# }
# 🍭Hey baby I'm sexy Kendra  💋Sweet submissive curvy exotic beauty  💕an experience you’ll never forget  💦 you’ll come back craving more guaranteed!!  ✨INCALL ONLY fun   ✨SPECIALS ✨$100-15min $150-30min $200-45mins $250-60min $300-90min  💋Multi hr 200/per hr  🔥Msog hh & up  ✨my prices are based off my SKILLS not your  wallet  🍭If you have a sweet tooth call me  💦Cum lets play✨No Rush✨  ☎✨Call (587) 834-6769 to book an appointment sweetheart  👑In life and luxury, some things never go on sale. I don't cater to low  ballers nor do I cater to disrespectful men.  💕NO negotiations pls & thank you  ❌NO BLOCKED/UNKNOWN CALLS‼❌  ⚠~SAFE PLAY ONLY~⚠  🚫ABSOLUTELY NO BB ANYTHING🚫  🚫NO BBBJ 🚫 ✔Cbj ONLY  ❎NO TRIPS TO GREECE✈ 👅  ❎NO CIM  ❎NO GROUPS  🚫I don't send/show pictures other then on site  ❌ low ballers, photo collecters & time wasters will be blocked immediatly ❌  ➡ Hygiene  is a must ✔ {
#   "text": "Kendra",
#   "type": "PERSON",
#   "start_char": 19,
#   "end_char": 25
# }
# 60 Quick  80 Half Hour  150 Hour  *100%   *100%  cs  iTs PlAy TiMe    Five-Star Experience I will leave you Satisfied. thickBlonde From the Moment we meet, you will be the center of my Attention.  Busty Double d38s for you to enjoy  Blue Bedroom Eyes  Italian & Irish **** N@ght KttTopNth P  Incalls ONLY !      !!  647-386-4369see you soon xoxo Brittany {
#   "text": "Brittany",
#   "type": "PERSON",
#   "start_char": 346,
#   "end_char": 354
# }
# BBW PRINCESS If YOU LOVE BBW'SYOU FOUND ME! I'm A True Companion With Unmatched skills and qualities...  More cushion for the pushin  vr Cl Cle & Cr 100% Rl i Gnrous N  BUSTY BBW VERY ADDICTIVE TOP NOTCH PLEASER  INCALLS TEXT@ (289) 233-7812 {
#   "text": "BBW PRINCESS",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 12
# }
# *Available  32d 5"1 110lbs 25waistFetishes welcome  New professional100% percent real and recent  OR SESSION IS FREEGentlemen I guarantee my pictures are 100% real no BS I value your time just as much as my reputation  what you see is exactly what getTherapeutic Massage  trained in massage. prostate massage I am well reviewed on Barrie Terb  Willing to travel to cottage countryPrivate EntrancePlease call  or text 249-359-7773 {
#   "text": "Barrie Terb",
#   "type": "PERSON",
#   "start_char": 331,
#   "end_char": 342
# }
# Hi I'm Coco 30y 5"4 36 D 120 Lbs Black Hair Light Tan Skin Tight Cookie no Texts no Private Call all area welcome yonge bloor  king queen Eglinton College Bay yorkville dufferin Yorkdale keele  Donwtonw Woodbridge mississauga etobicoke Vaughan    sorry no black gentsmen {
#   "text": "Vaughan",
#   "type": "PERSON",
#   "start_char": 236,
#   "end_char": 243
# }
# Gentlemen , I'm Jamayca. Your Nubian exotic Chocolate.im new to your City.  I'm 23 5'3 120pds. Smooth chocolate skin,petite & ready to give treats .  Call me for a unrushed time. Your best kept secret.  Sure to give you the time you've been waiting for. Come relax & release with me. Best  yet! Gentlemen Only  No private calls please. (916) 550-3365 {
#   "text": "Jamayca",
#   "type": "PERSON",
#   "start_char": 16,
#   "end_char": 23
# }
# New 21yr old girl , Giselle, fresh face of Toronto is here TODAY ! Big breast , exclusive and desirable service, top rated out of town , you won't ever regret it ! 100% REAL PHOTOS  Safe , discreet and clean!   For more details or booking :  Call or text at 6477956784 (texting preferred ) or email at chictorontoescort@gmail.com to book NOW !!! NO BLACK GENTLEMEN {
#   "text": "Giselle",
#   "type": "PERSON",
#   "start_char": 20,
#   "end_char": 27
# }
# Hi my nme is Aleey.  I'm  nughty, clssy & sensul frenchi from MTL. My bby fce with my beutifull eyes, my perfect lips nd my curves will mke you ddict. I m  pssionte, confident & ttrctive womn.  I provide  non-rushed & discreet service tht you won't forget. Pics re 100 % rel & recents.  Wht u see is wht u get here !!!    duo vil .    5'2 , 115lbs .  34D Nturl .  Text ONLY : 604-343-5992 .   SERiOUS iNQUiRES ONLY ! No Blck Men . {
#   "text": "Aleey",
#   "type": "PERSON",
#   "start_char": 13,
#   "end_char": 18
# }
# Guys, Mild to Wild  Call or text 7.7.8.8.3.9.9.9.9.0 NO Outcalls HOSTING MOTELMARLEE140 HOURauto hang up private numbersNO FETISHES/NO FEMALES/NO PICS {
#   "text": "Rauto",
#   "type": "PERSON",
#   "start_char": 91,
#   "end_char": 96
# }
# Hey my name is Lexy  I have everything you're looking for Catering to your every need 100% real, unedited pictures  Non rushed, Open minded & discreet services Classy Seductive Beauty  5Star Experience!  No Blocked Calls  No Unknown Calls Text or Call me 2892755684  Only Here This weekend !! Call Now!! Don't Miss Out 2892755684 {
#   "text": "Lexy",
#   "type": "PERSON",
#   "start_char": 15,
#   "end_char": 19
# }
# Hello sir, I was Lucy, 21y, young sexy girl in beautiful Singapore with lively breasts 36D, 5'4 and 108 pounds. Tight, delicious and beautiful face. In a warm shower to enjoy very much like kissing much.I what I do, I am committed to make you happy and comfortable A + service guaranteed! Service open to all menus. Miko also from South Korea. $ 60 New opening special! Call / TXT 647-638-1198 {
#   "text": "Lucy",
#   "type": "PERSON",
#   "start_char": 17,
#   "end_char": 21
# }
# Hello sir, I was Lucy, 21y, young sexy girl in beautiful Singapore with lively breasts 36D, 5'4 and 108 pounds. Tight, delicious and beautiful face. In a warm shower to enjoy very much like kissing much.I what I do, I am committed to make you happy and comfortable A + service guaranteed! Service open to all menus. Miko also from South Korea. $ 60 New opening special! Call / TXT 647-638-1198 {
#   "text": "Miko",
#   "type": "PERSON",
#   "start_char": 316,
#   "end_char": 320
# }
# I'm Susana aka Spice.                   If u ever wanted to be soaked.I'm the woman for u. I have curves in all the right places..Sensual and seductive.                                       I'm 5'4 160 lbs 38D. I have curly hair and killer blue eyes.  Amazing mouth!!! BOOTY PLAY!!!                 Waterfall Exprience!!                Low Restrictions!!!                 Call or text 416 726 1681            No blocked calls...Sun 12pm to 6pm {
#   "text": "Susana aka Spice",
#   "type": "PERSON",
#   "start_char": 4,
#   "end_char": 20
# }
# Hi gentlemen I'm Sasha. Guaranteed 5 star performance. I love polite and respectful gentlemen.   Filipino & Irish mix  125lbs/5'4/All Natural 34D's/Toned Booty 1000% REAL & Recent Pics Long Brunette Hair/Brown Eyes/Soft Skin  CLEAN & SAFE SERVICES  NO RUSH  Multi hrs/Overnights  Fetishes & Outfits Available Upon Request Text/Call (613) 604-5744  NO LOW BALLERS NO BLOCKED CALLS {
#   "text": "Sasha",
#   "type": "PERSON",
#   "start_char": 17,
#   "end_char": 22
# }
# ❤ Ready to fulfill your black girl fantasies ❤ Fresh & Tight! ? your perfect  Ebony Playmate? Slim body with an amazing round booth! ? YOUR PERSONAL DOLL  ? Come play with me.. I’ll give you an experience you’ll always remember ??  OUTCALL / INCALL {
#   "text": "Ebony Playmate",
#   "type": "PERSON",
#   "start_char": 78,
#   "end_char": 92
# }
# Maia Puerto Rican PERFECT BODY : Hour Glass Shape!! Pretty Face, Soft skin, Luxurious Curves Absolutely Addictive 289 273 0617 {
#   "text": "Maia Puerto Rican",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 17
# }
# Hey there I'm Anna. If you're looking for some satisfaction and pure pleasure, you've come to the right woman. My services are discreet and respectful, non rushed. 38DD all natural. Text me at 705 417 5498. I can't accept calls, my speaker does not work. {
#   "text": "Anna",
#   "type": "PERSON",
#   "start_char": 14,
#   "end_char": 18
# }
# BBW PRINCESS If YOU LOVE BBW'SYOU FOUND ME! I'm A True Companion With Unmatched skills and qualities...  More cushion for the pushin  vr Cl Cle & Cr 100% Rl i Gnrous N  BUSTY BBW VERY ADDICTIVE TOP NOTCH PLEASER  INCALL ONLYTEXT@ (289) 233-3445 {
#   "text": "BBW PRINCESS",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 12
# }
# Meeka koxxx !❤🤓💋👅  hello gentleman!!! im meeka i hope you all are enjoying your FRIDAY  i look forward to spending time with you ...  im lonely and horny constantly😏😘😘😘  come let me taste you!  👍GFE  👍PSE  👍DATY  👍BBBJ  👍BBFS circumstantial - case by case basis must be clean and disease free  👍CIP extra 50$  👍CIM / COF  fetishes extra  recording extra  friday special WATCH MY BF FUCK ME  then FUCK ME  IN CALLS ONLY AT BANFF TRAIL  cum see me i book up fast !! LOCATED BANFF TRAIL AREA AT A HOTEL  15 min sns 60$  30 min 100$  60min 160$!  INCALL ONLY  sexy exotic meeka offers a experience you will never forget  CLASSY SOPhISTICATED  text or call 5874015276 {
#   "text": "Meeka",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 5
# }
# Hi gentleman, I'm Celine, a sexy curvy latina. I'm fun, sweet and always super discreet.  I'm looking for a respectable gentleman to spend my time with, If this sounds like you then I would love to meet you! Don't be shy give me a call!   No cops.   Light Screening. NO EXPLICIT CONVO.  100% REAL PICS. I DON'T SEND PICS... SO DON'T ASK PLEASE!  SERIOUS INQUIRIES ONLY!! - 832 886 8504  CALL NOW OR BOOK YOUR APPOINTMENT FOR LATER {
#   "text": "Celine",
#   "type": "PERSON",
#   "start_char": 18,
#   "end_char": 24
# }
# Tia Busty brunette Brown eyed beauty  Luscious lips Perfect hips Petite body Available now Car/outcall Specials r for car only 80hh safe  200hr safe  Other services r availible however rates r different  Tia 587.447.9166 {
#   "text": "Tia Busty",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 9
# }
# Tia Busty brunette Brown eyed beauty  Luscious lips Perfect hips Petite body Available now Car/outcall Specials r for car only 80hh safe  200hr safe  Other services r availible however rates r different  Tia 587.447.9166 {
#   "text": "Brown",
#   "type": "PERSON",
#   "start_char": 19,
#   "end_char": 24
# }
# What's more fun then sinking your fingers into the soft wanton flesh of my unapologetically meaty thighs?  My specialty? Intense encounters, where the high of chemistry take over as your body intertwines with a near stranger. A delicious blend of sensuality, eroticism, tenderness and pure unbridled lust. A genuine G*F*E rampaging thru my dirty 30's. ~ smoke, drug and drama free. Beautiful upscale and private incall. Duo's available with Chantelle Stylez  Text   778-724-2496 {
#   "text": "Chantelle Stylez",
#   "type": "PERSON",
#   "start_char": 441,
#   "end_char": 457
# }
# Hello guys, This is Jess. 23yrs old independent hot Asian mix just arrived Newmarket. 34D-5'3-105lbs Very Addictive with Amazing Skills to Satisfy You. Are you Ready for HOT Steamy Experience? I Guarantee you will Crave for More...I LOVE what I do... I am Independent and NEVER RUSH for sure. NO EXPLICIT TALK NO BLACK GUYS Text now (647)2189939 Incalls only {
#   "text": "Jess",
#   "type": "PERSON",
#   "start_char": 20,
#   "end_char": 24
# }
# Hey gentlemen, I'm Chloe and I can't wait to please your every need Thick thighs, Beauty like no other. I promise I will leave you wondering why we haven't met sooner! 100% ME 36D 42inch booty all safe services upscale gents only DUOS available CALL ME NOW 6474950706 {
#   "text": "Chloe",
#   "type": "PERSON",
#   "start_char": 19,
#   "end_char": 24
# }
# Hi, I am Amanda, a 22 y/o Japanese girl.  ;) I am slimly (34D-23-33) with a curvy body.  I've smooth skin & a pretty face. Enjoy kissing & touching, love to have fun with you & I provide excellent service.   Guarantee you will feel relaxed with me. .     My friend Nana is a 24 y/o busty girl (36E 25 35) .   She is a Hot & Naughty.  Guarantee RELAXING & SENSUAL EXPERIENCE. DO NO-RUSH & OPEN-MIND, 100% NATURAL BODY! $80/hh Full Phone: 647-524-2536 @ Bathurst & Steeles {
#   "text": "Amanda",
#   "type": "PERSON",
#   "start_char": 9,
#   "end_char": 15
# }
# Hi, I am Amanda, a 22 y/o Japanese girl.  ;) I am slimly (34D-23-33) with a curvy body.  I've smooth skin & a pretty face. Enjoy kissing & touching, love to have fun with you & I provide excellent service.   Guarantee you will feel relaxed with me. .     My friend Nana is a 24 y/o busty girl (36E 25 35) .   She is a Hot & Naughty.  Guarantee RELAXING & SENSUAL EXPERIENCE. DO NO-RUSH & OPEN-MIND, 100% NATURAL BODY! $80/hh Full Phone: 647-524-2536 @ Bathurst & Steeles {
#   "text": "Nana",
#   "type": "PERSON",
#   "start_char": 265,
#   "end_char": 269
# }
# Hello Gentlemen  Nikki Jade here in ORILLIA, to cater to your every desire... Just ask! Let me spoil you with my natural talents, my refined skills, & my warm welcoming personality  Independent INCALLS ONLY ORILLIA NO BBFSNO blocked/APP #'s GRK friendly 30+ minutes notice please! FaceTime sessionsE-transfers TEXT ONLY: (647)-524-2764 {
#   "text": "Nikki Jade",
#   "type": "PERSON",
#   "start_char": 17,
#   "end_char": 27
# }
# STOP The pleasure is here come rejoinde me am waiting for u To do your fantasy 36D Natural 5.6 130 lbs. Blond am french canadian  dont miss me sexy curves Nice ass. Domination massage show  open minded   NO rush Time  always make your DK come Call me or text  1-587-410-7995 Ilimited Time Inn Town  Special meet me incall   Kassy baby {
#   "text": "Kassy",
#   "type": "PERSON",
#   "start_char": 324,
#   "end_char": 329
# }
# Hey there! I'm Imani the sexiest BBW you will ever meet. I have DD's, soft skin, pretty eyes, luscious lips and a massive ass. 6479528536 {
#   "text": "Imani",
#   "type": "PERSON",
#   "start_char": 15,
#   "end_char": 20
# }
# Hey my name is Jennifer make you feel aliveWoman of class&Quality.  I Take pride in my quality&Looks PICS ARE REAL I promise you'll be for morePassionate & sensual.Yet your dirtiest little secret..independent Discreet &Flexible Availabilities!Serious Inquires Outcalls/Incalls text/call (438)398-1788 New Girl In Town Last 24HoursBoys/Men Come & Get Wild With Sexy Jennifer! I Really Love My White Men & My Bikerz Francais AussiMorning Special Incall {
#   "text": "Jennifer",
#   "type": "PERSON",
#   "start_char": 15,
#   "end_char": 23
# }
# Hey my name is Jennifer make you feel aliveWoman of class&Quality.  I Take pride in my quality&Looks PICS ARE REAL I promise you'll be for morePassionate & sensual.Yet your dirtiest little secret..independent Discreet &Flexible Availabilities!Serious Inquires Outcalls/Incalls text/call (438)398-1788 New Girl In Town Last 24HoursBoys/Men Come & Get Wild With Sexy Jennifer! I Really Love My White Men & My Bikerz Francais AussiMorning Special Incall {
#   "text": "Jennifer",
#   "type": "PERSON",
#   "start_char": 365,
#   "end_char": 373
# }
# Hello My Name is Mitch your Matching Mitch...love to have fun with your fantasy mind!  Call me now... 365-777-1097 Mitch Let's rock the bed Baby... Come and have fun with me... {
#   "text": "Mitch",
#   "type": "PERSON",
#   "start_char": 17,
#   "end_char": 22
# }
# Hello My Name is Mitch your Matching Mitch...love to have fun with your fantasy mind!  Call me now... 365-777-1097 Mitch Let's rock the bed Baby... Come and have fun with me... {
#   "text": "Mitch",
#   "type": "PERSON",
#   "start_char": 37,
#   "end_char": 42
# }
# Hello My Name is Mitch your Matching Mitch...love to have fun with your fantasy mind!  Call me now... 365-777-1097 Mitch Let's rock the bed Baby... Come and have fun with me... {
#   "text": "Mitch",
#   "type": "PERSON",
#   "start_char": 115,
#   "end_char": 120
# }
# I am Bella You will like my looks like your college girl friend your never had. Im very short and slim with a very thin waist   647-546-5111 {
#   "text": "I am Bella",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 10
# }
# Hi Gentlemen, I'm Laura  Get away from your regular and tell me your fantasy, I'll make your dreams C U M true Indulge in extraordinary! Sexy, Classy, Sweet. Your Time with me is always relaxing, fun and NEVER rushed34C5"2110lbs Upscale, Classy & discreet professional FRIENDLY 100% Guarantee make youTime wasters will be blocked ONLY CONTACT ME WHEN YOUR READY  579-500-2966 {
#   "text": "Laura",
#   "type": "PERSON",
#   "start_char": 18,
#   "end_char": 23
# }
# Serious gentleman only. Please call also text me to confirm. Hello! I am Zoey I am a full Native American from Arizona. I am a Navajo. New phone number. I provide excellent services. Clean service None clock watcher Beautiful friendly soft attitude Percent real.I am 5'9, 36 c cup, very tone body.  I promise you won't be disappointed  Hh 160Hour 300Outcalls rates:160 hh300 hourDigits: 403-923-3224 {
#   "text": "Zoey",
#   "type": "PERSON",
#   "start_char": 73,
#   "end_char": 77
# }
# Hi guys, I am  Winnie, 20, 36D-24-35 Super Busty & Hot Girl. I want to be WILD & PARTY with anyone who appreciate my beauty & sexiness   Looking for the real deal in a mixed goddess queen? Naughty girl? You found me right here, enjoy the pleasure u deserve, satisfaction guaranteed! OpenMind  I can GUARANTEE u will leave C*R*A*V*I*N*G more!  ( Shower & Kiss Included)  DUOS Available with My Girlfriend - JOAN For Appointment, pls CALL or TXT - 403-390-5737 {
#   "text": "Winnie",
#   "type": "PERSON",
#   "start_char": 15,
#   "end_char": 21
# }
# Hello handsome  s e x y s e l e n a  My attitude will amaze you, my beauty will seduce you guaranteed! If you want to stop wasting your time with no shows and fake pictures, give me a call and you won't be disappointed. I've always been told I'm more beautiful in person!  Invigorating, Safe, Clean & Unrushed  **INCALL/OUTCALL ALL NIGHT ** 647-880-7531 Please be discrete and respectful when calling  Selena {
#   "text": "Selena",
#   "type": "PERSON",
#   "start_char": 402,
#   "end_char": 408
# }
# Hi there, I'm Layla! Hi,I am Lemon~I am a perfect "party girl", sexy and seductive this South-Eastern Asian, black haired beauty is a guaranteed winner to brighten up any day or night.Accept credit or debit cards CALL: 416-823-5266 {
#   "text": "Layla",
#   "type": "PERSON",
#   "start_char": 14,
#   "end_char": 19
# }
# Hi there, I'm Layla! Hi,I am Lemon~I am a perfect "party girl", sexy and seductive this South-Eastern Asian, black haired beauty is a guaranteed winner to brighten up any day or night.Accept credit or debit cards CALL: 416-823-5266 {
#   "text": "Lemon",
#   "type": "PERSON",
#   "start_char": 29,
#   "end_char": 34
# }
# Hey I am Angela, 21 yrs Asian girl from Japan!  Allow me to Help you Escape to your Pleasure ZONE!  I am Selective, Just as you are. So Please be a Gentleman over the phone  NO Explicit Talk & Definitely NO Games...!!  Treat Yourself to an Unforgettable Time!  You Deserve Nothing but the Best...I Promise you won't be Disappointed!  Here for SHORT TERM only. BOOK NOW While im still available!  CALL ME NOW: 289-489-9588 {
#   "text": "Angela",
#   "type": "PERSON",
#   "start_char": 9,
#   "end_char": 15
# }
# My names Barbie im a Beautiful FRIENDLY & OUTGOING I can guarantee you a moment ofUNFORGETTABLE events... Looking for something truly SEXY and UNIQUE.. iM THE PRFCT COMBINATION ... I KNOW WHAT YoU WANT BABy!  EvEN BeTTeR iN PeRSoN! I'm ALWAyS ReADy 4 FuN! Try Me 587-782-5054 XOX for your personalized naughty picture of me for extra 20 $ 40 $ for nude with your name written on me emailed at {
#   "text": "Barbie",
#   "type": "PERSON",
#   "start_char": 9,
#   "end_char": 15
# }
# Credit card Accepted!! I'm Carol, 20 yr-old BUSTY, BEAUTIFUL & SEXY.  I just arrived in the town, brings you a very special treat from Asia. I am the perfect companion.  I am 35D-24-35, Sweet & ALL NATURAL body 5'4 tall with 110lbs, amazing butt.  I offer good service and we can have lots of fun together. Anything OK & Never Rush!  24/7 LINGERIE STOCKING HIGH HEELS My friend Miki is ready too.  Call: 416-902-0826 (No Txt Pls.OUTCALL ONLY) {
#   "text": "Carol",
#   "type": "PERSON",
#   "start_char": 27,
#   "end_char": 32
# }
# Credit card Accepted!! I'm Carol, 20 yr-old BUSTY, BEAUTIFUL & SEXY.  I just arrived in the town, brings you a very special treat from Asia. I am the perfect companion.  I am 35D-24-35, Sweet & ALL NATURAL body 5'4 tall with 110lbs, amazing butt.  I offer good service and we can have lots of fun together. Anything OK & Never Rush!  24/7 LINGERIE STOCKING HIGH HEELS My friend Miki is ready too.  Call: 416-902-0826 (No Txt Pls.OUTCALL ONLY) {
#   "text": "Miki",
#   "type": "PERSON",
#   "start_char": 378,
#   "end_char": 382
# }
# Tiz the SeAsOn for this mature HoRnY BBW to ExPrEsS how VERY GrateFULL she is for the KiNdHeArTeD PeoPle who have taken time to visit! Hoping to see all my PeePs out this month to  SpReAd  GOOD CHeeR and  ToAsT  to ALL the BeSt in the NeW YeaR with a host of PRIZES and GIVEAWAYS!!! Enjoy my blog http://bbwjust4you.com  LooK for the remainder of my BP ad! Short in TxT, Tall on Service 204-800-7451 Sylvie {
#   "text": "PeoPle",
#   "type": "PERSON",
#   "start_char": 98,
#   "end_char": 104
# }
# Tiz the SeAsOn for this mature HoRnY BBW to ExPrEsS how VERY GrateFULL she is for the KiNdHeArTeD PeoPle who have taken time to visit! Hoping to see all my PeePs out this month to  SpReAd  GOOD CHeeR and  ToAsT  to ALL the BeSt in the NeW YeaR with a host of PRIZES and GIVEAWAYS!!! Enjoy my blog http://bbwjust4you.com  LooK for the remainder of my BP ad! Short in TxT, Tall on Service 204-800-7451 Sylvie {
#   "text": "Sylvie",
#   "type": "PERSON",
#   "start_char": 400,
#   "end_char": 406
# }
# VISITING CALGARY  Hey Gentleman I'm Amanda Thick Chocolate Goddess  With a pretty Smile  No rushed services  Im very Sensual   Pretty Face Juicy Lips  38DD Breast..165LBS 1OO% real photos < Indepandante woman Incall & Outcall everywhere avaible  I cater to mature respectful Gents only, I love mature men Duo avaible / Party  Couples, Role-playing, multi-hr or overnight stays!! Special. Texr me babe 647 317 7830 No black Man {
#   "text": "Amanda Thick",
#   "type": "PERSON",
#   "start_char": 36,
#   "end_char": 48
# }
# VISITING CALGARY  Hey Gentleman I'm Amanda Thick Chocolate Goddess  With a pretty Smile  No rushed services  Im very Sensual   Pretty Face Juicy Lips  38DD Breast..165LBS 1OO% real photos < Indepandante woman Incall & Outcall everywhere avaible  I cater to mature respectful Gents only, I love mature men Duo avaible / Party  Couples, Role-playing, multi-hr or overnight stays!! Special. Texr me babe 647 317 7830 No black Man {
#   "text": "Duo",
#   "type": "PERSON",
#   "start_char": 305,
#   "end_char": 308
# }
# Good conversation and sense of humor I'm in a frisky mood! Are you? Get a llllllload off your mind, Private room Voluptuous,  bubbly woman anxious to meet  you I will treat you the way you deserve, let me take care of your needs Giving and receiving  of massages , enjoy my company and magic fingers Let me stimulate you.Toes will curl.Let me get rid of the stress of the day, safe playBrown Hair, Hazel eyes, 40DD real Arriving afernoon Tues. 2 nights at Rama226 239 8505PHONE CALLS ONLY {
#   "text": "Hazel",
#   "type": "PERSON",
#   "start_char": 398,
#   "end_char": 403
# }
# WARDEN & 401 (Howard Johnson) MONDAY 3PM-3AM www.rockinrobin2015.com Robin 5'3 & 125lbs beautiful brunette with baby blue eyes INDULGE YOURSELF! My EXTENSIVE MENU includes a hot oil massage/reverse, fetish/role play, shower play, bubble bath for 2 LETS HAVE SOME FUN! 416-660-8466 or @GFERobin69 NEAR:bloor danforth dvp don mills eglington lawrence wynford york mills 401 & 404 victoria park o'connor st.clair warden ellesmere sheppard finch pharmacy  birchmount kennedy {
#   "text": "Howard Johnson",
#   "type": "PERSON",
#   "start_char": 14,
#   "end_char": 28
# }
# Hello Gentlemen! Beautiful sexy busty blonde available to pamper you! 38ddd-33-37 Gorgeous face, amazing personality, very down to earth and super sexy! Incall 5 minutes from 401.  Safe, discreet and private. Shower and parking available.Outcalls to Oshawa, Whitby, Ajax, Bowmanville, Port Hope, Cobourg, Uxbridge, Toronto and surrounding areas. Available Sunday, Monday and Thursday. Meghan Xoxo 647-710-4077 {
#   "text": "Meghan Xoxo",
#   "type": "PERSON",
#   "start_char": 385,
#   "end_char": 396
# }
# Touring date: Oct 21-24th Hi gentlemens, I am Marianna Fuentes, a Classy, charming, witty & educated, I am a true pleasure to spend time with. I can be intense & passionate, or fun and playful. Look no further. I will delight and impress you.  iNDEPENDENT   5'3" 130lb 34D    & s  SAFE AND DiSCREET   NO RUSH SERViCE  Text meNow! TERB & SP411 Girl 647-498-0632 {
#   "text": "Marianna Fuentes",
#   "type": "PERSON",
#   "start_char": 46,
#   "end_char": 62
# }
# S E N S U A L and discreet!  Sweet and E X C I T I N G! Open Minded Smooth silky chocolate skin Amazing skills D U O and fetish friendly 5"7, 125lbs, 34B 100% REAL & RECENT PICS  NO RUSH NO BLACK GENTS  343-998-4875 Ask for JESSICA Outcall & Incall Email transfert available {
#   "text": "JESSICA Outcall",
#   "type": "PERSON",
#   "start_char": 224,
#   "end_char": 239
# }
# Hello my name is Nakysha , i am 23 year, 140lbs, 5'7 ", 36D, very natural , elegant and charming. I invite you to discover the charm of a young very sweet girl for a pleasant meeting full of eroticism and sensuality. I prefer dating qualities and , RESPECTFUL, PLEASANT and COURTEOUS GENTLEMAN PLEASE, willing to spend good moments in my company. I offer a high quality service in the utmost discretion to ensure you have the Best moment possible .  See you soon I hope Nakysha  (403)618-3014 {
#   "text": "Nakysha",
#   "type": "PERSON",
#   "start_char": 17,
#   "end_char": 24
# }
# Hello my name is Nakysha , i am 23 year, 140lbs, 5'7 ", 36D, very natural , elegant and charming. I invite you to discover the charm of a young very sweet girl for a pleasant meeting full of eroticism and sensuality. I prefer dating qualities and , RESPECTFUL, PLEASANT and COURTEOUS GENTLEMAN PLEASE, willing to spend good moments in my company. I offer a high quality service in the utmost discretion to ensure you have the Best moment possible .  See you soon I hope Nakysha  (403)618-3014 {
#   "text": "Nakysha",
#   "type": "PERSON",
#   "start_char": 470,
#   "end_char": 477
# }
# Hi my name Gina Europe 33 years old  no blocked number, no black men my pictures are 100% real! If you looking for good time call me 4165624051 {
#   "text": "Gina Europe",
#   "type": "PERSON",
#   "start_char": 11,
#   "end_char": 22
# }
# Hi guys Im Ashely Dupre Petite and horny  Juicy tight p***y  Mulitiples hours & Overnight Fetishes/Pegguin/Strap/Toys/Massage Tha/ golden  420 Friendly  Incall &Outcall  No rush  No waist  Independent Classy & Tiny Pretty face No black gentleman  No explicite call or txt Call me or text me Baby  Ashely Dupre 647-308-3490 {
#   "text": "Ashely Dupre",
#   "type": "PERSON",
#   "start_char": 11,
#   "end_char": 23
# }
# TODAY's SPECIAL - Your dream girl, Kay is back KAY  Age:19 5'3 - 108 lb, 36D-24-35(SINGAPORE) Super Model with killing body & busty, Long Legs Lina  Age:20 5'4 - 105 lb, 34C-24-35 (Korean) OpenMinded Student short term Partime CHERRY  Age:19 5'4, 105lbs, 34DD-24-34 Student with Petite body & gorgeous face NO-RUSH & 1OO% REAL PIC We guarantee YOU will love to see us! $60 SPECIALS TODAY OR $120 (2 TIMES) *You can see us in person* PLEASE CALL: 416-625-3626  LOCATION : KENNEDY RD SOUTH / STEELES (BRAMPTON) {
#   "text": "Kay",
#   "type": "PERSON",
#   "start_char": 35,
#   "end_char": 38
# }
# Hi, I am Ci Ci,Korea model girl  I am EVERY man dream girl. High Quality  Treatment at its FINEST Roommie D D From Singapore is NEW to business, 100% Satisfaction!  Very OPEN-MINDED menuGuarantee RELAXING & SENSUAL EXPERIENCE!  Uniforms & Cosplay  Magic Hand With Best Young Girls No-Rush * 100% recently pics Stockings High Heels Sexy Lingerie Role Play & More!! Call Me 416-904-7899 {
#   "text": "Ci Ci",
#   "type": "PERSON",
#   "start_char": 9,
#   "end_char": 14
# }
# hey I am Kim ,HOT Luxury,Passionate,Elegant, Romantic woman. Looking 4 Something Special & a Little Different, Some Adventure& to Help You To Forget Your Everyday Cares & Stress.Lets cuddle it's cold out Then Here I Am. The First Step To a Lovely, Unforgettable Time Together. My Wardrobe Extends From The Classic To The Fashionable, From The Chic To The  Seductive! My Lingerie Is Very Sexy &  Elegant.I know Very Well What a Real man Loves! 6134177358. {
#   "text": "Kim",
#   "type": "PERSON",
#   "start_char": 9,
#   "end_char": 12
# }
# Hello Gentlemen ,Im 5'5 with a Gorgeous body, great personality and will make u feel like a KING and im the Queen of anala. My name is stacy and ready to see you in Calgary  I am a very relaxed and an easy going person and offer a fantastic, non-rushed, enjoyable experience.  My pics are 100% REAL! So what are u waiting for?? I enjoy what i do!! I'm always Ready to give u a jaw dropping Amazing experience everytime text now    6137908494 INCALL AND OUTCALL! {
#   "text": "the Queen of anala",
#   "type": "PERSON",
#   "start_char": 104,
#   "end_char": 122
# }
# Drop Dead Gorgeous treat  A MUST SEE 4 those who desire a Naughty Skilled Playful Girl No black guys No Exceptions(647)499-3482 Amanda {
#   "text": "Amanda",
#   "type": "PERSON",
#   "start_char": 128,
#   "end_char": 134
# }
# I take pride in being discreet, respectful, down to earth & prefer to meet those who are the same. I cater to the selective gentleman.  If you're looking for a cheap thrill, I'm not the girl for you! I'm tanned & slim w/a curvy figure 5'8125 lbs36B-24-36   non-smoker Real & Recent Photos & Video. Who you see is me... GUARANTEED! Victoria Park/401 Private clean apartment.  Outcalls NOT available! CALL HAILEY 647-247-9627 OR CALL/TEXT 647-491-6466 NO blocked or payphone calls NO emails please. {
#   "text": "Victoria Park",
#   "type": "PERSON",
#   "start_char": 331,
#   "end_char": 344
# }
# Hello Gentlemen; my name is Andrea. ?  You'll adore my flirtaciousness combined with my confident attitude. You'll be  amazed by the way I can make all your senses tingle! I promise to u won't feel  anything less than complete satisfaction. ? I am: 24 - 5'3" & 117lbs with 32DD  ? Smooth Skin > Brown Eyes ? Discreet > Professional > Independent  ? Outcall & Safe-Play Only  ? Respectful Serious Inquiries Please  1 hour 30$  2 hour 50$  3 hour 100$  ☎ Text Only ?: (717) 928-7964 xox  (I don't answer phone calls {
#   "text": "Andrea",
#   "type": "PERSON",
#   "start_char": 28,
#   "end_char": 34
# }
# Hello Gentlemen; my name is Andrea. ?  You'll adore my flirtaciousness combined with my confident attitude. You'll be  amazed by the way I can make all your senses tingle! I promise to u won't feel  anything less than complete satisfaction. ? I am: 24 - 5'3" & 117lbs with 32DD  ? Smooth Skin > Brown Eyes ? Discreet > Professional > Independent  ? Outcall & Safe-Play Only  ? Respectful Serious Inquiries Please  1 hour 30$  2 hour 50$  3 hour 100$  ☎ Text Only ?: (717) 928-7964 xox  (I don't answer phone calls {
#   "text": "Brown",
#   "type": "PERSON",
#   "start_char": 295,
#   "end_char": 300
# }
# Hey gentlemen and ladies ..  Are you ready to taste Bella is ready to play  ✨SEXY CURVES & MAGIC MOUTH✨  Sexy Fun Sized  Your satisfaction is my #1 priority  5’0 110 lbs 34C  Perfect Tight Body & Perfect tight Pu$$y  A1 Upscale Service ALWAYS Fresh  ✔️Available Now for Outcalls  ✔️NO Rush  ❌No blk gents under 40 and no blocked calls❌  438-229-0166 Bella {
#   "text": "Bella",
#   "type": "PERSON",
#   "start_char": 52,
#   "end_char": 57
# }
# Hey gentlemen and ladies ..  Are you ready to taste Bella is ready to play  ✨SEXY CURVES & MAGIC MOUTH✨  Sexy Fun Sized  Your satisfaction is my #1 priority  5’0 110 lbs 34C  Perfect Tight Body & Perfect tight Pu$$y  A1 Upscale Service ALWAYS Fresh  ✔️Available Now for Outcalls  ✔️NO Rush  ❌No blk gents under 40 and no blocked calls❌  438-229-0166 Bella {
#   "text": "Bella",
#   "type": "PERSON",
#   "start_char": 350,
#   "end_char": 355
# }
# Love what I do and very discreet  Serious inquiry only independent  % reall pics party girl love regulars No explicit texts  No pics request  No block calls I'm Samantha  Text only 7808846377 {
#   "text": "Samantha  Text",
#   "type": "PERSON",
#   "start_char": 161,
#   "end_char": 175
# }
# Hey gentlemen I'm Caitlin  I am available now leave rest come to the best  I will leave you in P A R A D I S E  D e  p throat Skills && Splash Talents , I am a down to earth and will go above and beyond to leave you satisfied My stats are 5"5 175 lbs D34 33 waist 48 A $$   No Blocked calls no black gentlemen  Text NOW  289-921-1825 {
#   "text": "Caitlin",
#   "type": "PERSON",
#   "start_char": 18,
#   "end_char": 25
# }
# **** INDEPENDENT **** I am Amy a beautiful Chinese girl. I am 5'4" with 36c breasts, pretty face and pretty feet Call me for a great massage, or stockings and foot fetish OR Jessica a seductive chinese girl Hurontario and Central Parkway, easy acccess, plenty of parking Private, clean location call or text 416-839-8715 for details PLEASE DO NOT SEND EMAILS. BLOCKED CALLS WILL BE IGNORED {
#   "text": "Amy",
#   "type": "PERSON",
#   "start_char": 27,
#   "end_char": 30
# }
# Outcalls & Incalls! Available for mature and Discreet gentleman. ;)   Message Misty...450-499-3509 {
#   "text": "Misty",
#   "type": "PERSON",
#   "start_char": 78,
#   "end_char": 83
# }
# PLEASE read my entire ad, that way neither of us waste our time! thank you  very much!  - - - - -  - - - - -  Im a totally submissive girl who loves to have hard, wild, crazy fun; but also  loves it slow and sensual❣Anyway you give it, i love it❣  - - - - -  - - - - -  ⚠AVAILABILITY FOR TUESDAY-FRIDAY, SEPTEMBER 3-6th:  - - - - -  DAY AVAILABILITY NOT GAURENTEED  - - - - -  ⚠ when i wake up until 7PM ~> CAR DATE ONLY! (ABSOLUTELY NO🚫INCALL!)  - - - - -  ⚠7PM until i go to bed ~> CAR/ OUTCALL ONLY! (ABSOLUTELY NO🚫INCALL!)  - - - - -  - - - - -  🚫Services not offered by me: BB, NO-LIMIT, DOMINATION, PARTYING, and I DO  NOTNEGOTIATE MY RATES OR SERVICE!  ⚠UNFORTUNATELY I'm not MOBILE so  transportationwill need to be provided by  you!  - - - - -  - - - - -  💰MY MINUMUM rate is💲60 for a SNS CBJ only! My rates go up from there; so  please only text if you are able and willing to provide this  - - - - -  - - - - -  Why hello darlin'!  - - - - -  My name is Charlie, Im a 23 year old 'BBW' alternative gal with tons of booty,  and tattoos/dyed hair! I absolutely LOVE to please! I love to laugh, have fun,  and I adore making others laugh and smile! My personal fetish, is pleasing your body and mind!  💯% REAL  💯% TIGHT  💯% YOUNG  💯% DrugDiseaseFree  - - - - -  ⚠Please ask me about the submissive extras I offer on top of my basic rates as  I love having a red bottom, and love my hair pulled!  - - - - -  - - - - -  ⚠Please TEXT ONLY as I don't receive phone calls: 1.587.402.3786⚠  - - - - -  - - - - -  🖤SAFE - SANE - CONSENTUAL PLAY TURNS ME ON💜  - - - - -  👅I can't wait to make your evening better! If you'd like, I know some great  places to Park'n'Ride by my place in Queensland!💋 {
#   "text": "BB",
#   "type": "PERSON",
#   "start_char": 579,
#   "end_char": 581
# }
# ...
#   "text": "Samantha",
#   "type": "PERSON",
#   "start_char": 369,
#   "end_char": 377
# }
# Christin -really is the full package, a fabulous mix of sugar and spice, in fact a real sweetie. She is up for anything and everything you want to party? Vivian a very lovely, petite and cuddly body which is complemented by having a very cute smile. A very attractive Asian Escorts with an excellent body which is well proportioned and natural in all aspects. www.torontoescorts.mobi (416-666-1322) (Please allow 1 hour advance notice) {
#   "text": "Christin",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 8
# }
# Christin -really is the full package, a fabulous mix of sugar and spice, in fact a real sweetie. She is up for anything and everything you want to party? Vivian a very lovely, petite and cuddly body which is complemented by having a very cute smile. A very attractive Asian Escorts with an excellent body which is well proportioned and natural in all aspects. www.torontoescorts.mobi (416-666-1322) (Please allow 1 hour advance notice) {
#   "text": "Vivian",
#   "type": "PERSON",
#   "start_char": 154,
#   "end_char": 160
# }
# Hi! I'm Elizabeth a Korean beauty. I can be reach at 647-401-6512 or visit my site at www.torontofemaleescort.com {
#   "text": "Elizabeth",
#   "type": "PERSON",
#   "start_char": 8,
#   "end_char": 17
# }
# The Lady of Your Naughtiest Dreams  !!!(  Real ) & (  Recent Pics ) Gentlemen Only Upscale slim/thick Sexy Bombshell  Hour Glass Figure  Gorgeous Face* Bedroom Eyes Fetish Friendly Fun Personality  Promise to Satisfy and Never Rush!  100% Real and Recent Pictures!!! No attitude! Always Discreet & Drama Free 1 Of Kind Girl   Sarah Lynn   SERIOUS INQUIRIES ONLY  Call or text 226-241-8626DELHI CARCALLS ONLY {
#   "text": "The Lady of Your Naughtiest",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 27
# }
# The Lady of Your Naughtiest Dreams  !!!(  Real ) & (  Recent Pics ) Gentlemen Only Upscale slim/thick Sexy Bombshell  Hour Glass Figure  Gorgeous Face* Bedroom Eyes Fetish Friendly Fun Personality  Promise to Satisfy and Never Rush!  100% Real and Recent Pictures!!! No attitude! Always Discreet & Drama Free 1 Of Kind Girl   Sarah Lynn   SERIOUS INQUIRIES ONLY  Call or text 226-241-8626DELHI CARCALLS ONLY {
#   "text": "Sarah Lynn",
#   "type": "PERSON",
#   "start_char": 326,
#   "end_char": 336
# }
# Angel 58 Milf Tall Curvy Busty Blonde Blue Eyes Medium BBW 510 180lbs All Natural 48 DDDz 36 48 Long Flexible Legs. Very Experienced n Unique. Will leave you surprised n weak in the knees. QFNS ONLY $80 COWGIRL $80 SpEcIaL ridem cowgirl ey ha  . Ill smother you with my big bouncy boobies n bust ur nuts. Other packages also available!  I also offer Sexting Phone Chat Video Play n Tarot Reading at a great rate. Its not cheating if ur on the phone. Angel xox Luvzu ... 647-797-6512 ... 24/7 Message me Anytime ... Sweet Heart {
#   "text": "Angel xox Luvzu",
#   "type": "PERSON",
#   "start_char": 450,
#   "end_char": 465
# }
# Hey guys , My name is Carmen. I'm a all natural BIG breasted & big booty an a sexy small BBW curves woman, with long Blonde hair pretty face . I specialize in giving massages before we get into the real FUN like toys for extra ! I LOVE making a man feel good about themselves, something about that makes me feel good about myself Or should I say makes me feel good(wink wink)... If you are interested in ANYTHING listed, call me CARMEN 647-883-4855 {
#   "text": "Carmen",
#   "type": "PERSON",
#   "start_char": 22,
#   "end_char": 28
# }
# my name is Catalina I have an awesome caramel smooth skin and long blond hair and a charming personality. just arrived in town and came to pamper you. Im always beautiful and would love to take care of you how you deserve it *100% real and recent pictures *Satisfaction guaranteed *Safe, clean and unrushed *Discreet and classy Incalls/outcalls in beautiful condo d/town Text/call:438-792-7612 Cafreviews =catalina {
#   "text": "Catalina",
#   "type": "PERSON",
#   "start_char": 11,
#   "end_char": 19
# }
# My name is Christine I have red hair freckles and green eyes. I provide excellent non rushed services in Scarborough morningside And Lawrence area. {
#   "text": "Christine",
#   "type": "PERSON",
#   "start_char": 11,
#   "end_char": 20
# }
# Hey Guys,  I'm mature, Fun loving, Clean and Private FaceSitting First time S+Rap on RoleplayingGo24;den Tease&Denialprostate massage Sissy/maidForced Feminization Body worship A55 worship with Hot oilFoot Fetish  tickle torture $ Fin Dom $ubmissive sugar dad Corpreal Punishment In/outcallsKitchener.  Text/Call 226-336-9766 Mistress Val {
#   "text": "Val",
#   "type": "PERSON",
#   "start_char": 335,
#   "end_char": 338
# }
# Hi Gentleman,my name Nora lam Lol girl Relax and easy person,Text me for more info. let's get together & I speak a bit English. Text me better. Please only texting.  289-681-9954?? No out call.No blocked  100 % Really pic 170 cm 52kg 36d {
#   "text": "Nora",
#   "type": "PERSON",
#   "start_char": 21,
#   "end_char": 25
# }
# Salut Cheri je suis kayla belle femme bbw de 20ans , je suis libre pour rencontre serieuse seulement je suis une vraie femme dexperience ( tres soumise , et fontaine )  !! Jaime le plaisir intense! Quoi de mieux qune bonne baise a 4 pattes ;) Texte moi :* 438-794-5208 au plaisir de te rencontrer :) {
#   "text": "Quoi de mieux",
#   "type": "PERSON",
#   "start_char": 198,
#   "end_char": 211
# }
# Hey Boys!!! Im Jenn  The perfect combination of a sultry vixen & girl next doorAlways discrete & No drama Passionate&fun 5878076434 {
#   "text": "Jenn",
#   "type": "PERSON",
#   "start_char": 15,
#   "end_char": 19
# }
# Hi I am Nikki  Nordisch Easy going and I love  to be fit ! Text or call (705) 345-08165'2 108 pounds {
#   "text": "Nikki  Nordisch",
#   "type": "PERSON",
#   "start_char": 8,
#   "end_char": 23
# }
# Hello gentlemen my name is Ginger .  I am a slender build , 5'4" tall and 130 pounds. I'm looking for a "Sugar Daddy", that will take care of me and I will for sure take care of my Daddy"br>  (call only if a serous inquiry pls)  I am fun, outgoing,and love to be a lady, but a tease behind close door..... If you're interested please give me a call or text , 403-615-9819. ( Out calls only.) {
#   "text": "Ginger",
#   "type": "PERSON",
#   "start_char": 27,
#   "end_char": 33
# }
# Hi. gentleman. My name is Sora Asian pretty princess visiting Markham for 2  days.  Upscale Hotel.  226-7516902 ( Sora)  hwy7 & 404 (Markham) {
#   "text": "Markham",
#   "type": "PERSON",
#   "start_char": 62,
#   "end_char": 69
# }
# Hey were Alex and Kayla we wanna show you how we play. We want you to tell us what you want to see. We host to couples also. We're not hi sexual more hi curious open minded try to make you feel as comfortable as possible. Kayla is a 5'6 130lbs with perky 34Cs Alex is 5"11 8-8.5" Cut 160/lbs. We host you in Gatineau and are party favor friendly also 420/friendly. Text or call (819) 315-1789 come have some fun tonight !!! {
#   "text": "Alex",
#   "type": "PERSON",
#   "start_char": 9,
#   "end_char": 13
# }
# Hey were Alex and Kayla we wanna show you how we play. We want you to tell us what you want to see. We host to couples also. We're not hi sexual more hi curious open minded try to make you feel as comfortable as possible. Kayla is a 5'6 130lbs with perky 34Cs Alex is 5"11 8-8.5" Cut 160/lbs. We host you in Gatineau and are party favor friendly also 420/friendly. Text or call (819) 315-1789 come have some fun tonight !!! {
#   "text": "Kayla",
#   "type": "PERSON",
#   "start_char": 18,
#   "end_char": 23
# }
# Hey were Alex and Kayla we wanna show you how we play. We want you to tell us what you want to see. We host to couples also. We're not hi sexual more hi curious open minded try to make you feel as comfortable as possible. Kayla is a 5'6 130lbs with perky 34Cs Alex is 5"11 8-8.5" Cut 160/lbs. We host you in Gatineau and are party favor friendly also 420/friendly. Text or call (819) 315-1789 come have some fun tonight !!! {
#   "text": "Kayla",
#   "type": "PERSON",
#   "start_char": 222,
#   "end_char": 227
# }
# Hi guys I'm Alex   &     I stand 5'3. I have amazing 34DD. Beautiful eyes. Eastern European Beauty   Body type is petite and tight just right with a cute butt I'm adult entertainer I can bring you to your knees in teasing. Offer entertainment for bachelor and birthday parties just ask!  ALWAYS Fresh  Unrushed  Discreet   Outcalls only  Call or text me ;) 2264991015 P.s Ask me about my outfits feel free to request something! {
#   "text": "Alex   &     I",
#   "type": "PERSON",
#   "start_char": 12,
#   "end_char": 26
# }
# Hi gentlemeny My name Karina  I am  Colombia 30 years old. Sexy and good body. Your service for a new hot experience with a woman very open minded, wanna have good and funny time. Call me now at 647-767-1900 waiting  for you 24/7 , My location {
#   "text": "Karina",
#   "type": "PERSON",
#   "start_char": 22,
#   "end_char": 28
# }
# French & Amerindienne Nyna very big juicy Boooty. Hot & Sweet Lips 27 5'7 300lbs 52DD .. Come play with my curves and my sexy bigbody.Expertwith my mouth and fulll another things. incall Just try me baby 514 448 7828 (pie9 and 42e street ) {
#   "text": "Boooty",
#   "type": "PERSON",
#   "start_char": 42,
#   "end_char": 48
# }
# Hi Guys ,my name is Galya, if you are looking for Company, text me please 289  489 4724  I do not have a place . {
#   "text": "Galya",
#   "type": "PERSON",
#   "start_char": 20,
#   "end_char": 25
# }
# Harley Splitz!!I always have a special on!  Call or text me for details:) (403)690-3066Or(587)779-9429 {
#   "text": "Harley Splitz!!",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 15
# }
# My goal is to relax and please youI am professional and curvy in all the right placeslet me treat you like a king that you areand take the stress of the world off your mind and show you the best time of your life  Soft skin  100% safe low-ballers will be blocked No black men ! Funny,flirty and erotic Let me be your best kept secret  Ask for Valentina 8189639909 {
#   "text": "Valentina",
#   "type": "PERSON",
#   "start_char": 343,
#   "end_char": 352
# }
# Hi I'm Shay-lynn I'm 31 long blonde hair C38 curvy great butt stunning body open minded and playful.I offer a great snack anytime 2265005852 {
#   "text": "Shay-lynn",
#   "type": "PERSON",
#   "start_char": 7,
#   "end_char": 16
# }
# ATTENTION BUSINESS MEN PLZ! Sexy Lexy can make all our Dreams ,Fantasies ,Fetishes take real action,  that night w the ONE n only SEXY LEXY.,,,AKA Mouth-Queen. 100% satisfaction always GUARNTEED & NO Rush! INDEPENDENT* SAFE* REAL UPDATED PHOTOS* OUTCALLS 200$  Hr pending on LOCATION?  CARCALLS 80$ 15 mins only INCALL R LIMITED 120$ Hf.  U want da  real deal.  always a SATISFIED ending!  EMAIL LEX @ sexy82lexy@gmail.com all adds will not go UNANSWERED.. R TXT 2899759744 r 2896894983 {
#   "text": "Sexy Lexy",
#   "type": "PERSON",
#   "start_char": 28,
#   "end_char": 37
# }
# Hi my name it's Sophia Busty Babe Seeking Great Time With you Gentleman  Passionate and love to french kiss i am PLYFul BBE  who want YOU as a rgulr!  Lets turn up the het tonight!!  Your SXy Plymtes!! You'll LOVE us!  WE Have Gorgeous Ftures   Muth Wtring Sklls that will BLW  your MND   Non rsh srvce  PARTY FAVORS AVAILABLE/ Overnight stay  Text me now : 587-408-7092 {
#   "text": "Sophia Busty",
#   "type": "PERSON",
#   "start_char": 16,
#   "end_char": 28
# }
# Hi my name it's Sophia Busty Babe Seeking Great Time With you Gentleman  Passionate and love to french kiss i am PLYFul BBE  who want YOU as a rgulr!  Lets turn up the het tonight!!  Your SXy Plymtes!! You'll LOVE us!  WE Have Gorgeous Ftures   Muth Wtring Sklls that will BLW  your MND   Non rsh srvce  PARTY FAVORS AVAILABLE/ Overnight stay  Text me now : 587-408-7092 {
#   "text": "SXy Plymtes",
#   "type": "PERSON",
#   "start_char": 188,
#   "end_char": 199
# }
# Hey guys!! it's Kiki I am available at my private upscale condo at holdom station. This is approx 25 mins from dt van if you drive or take transit. I do not offer grk, c!m, |3|3f$, cf  I am Columbian with beautiful gold skin. 100% Independent!!  NO Rush Guaranteed Real Pics Clean Condo w/ Fresh Towels and Sheets No explicit Talk please! Call me 6043342906 For discretion I do not reply to msgs that are more than an hour old. {
#   "text": "Kiki",
#   "type": "PERSON",
#   "start_char": 16,
#   "end_char": 20
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-ee63cfb095a2> in <module>
#       1 c = 0
#       2 for ad in tqdm(ad_texts):
# ----> 3     ents = nlp(ad).entities
#       4     for entity in ents:
#       5         #print(type(entity))
#
# /usr/local/lib/python3.6/dist-packages/stanza/pipeline/core.py in __call__(self, doc)
#     164         assert any([isinstance(doc, str), isinstance(doc, list),
#     165                     isinstance(doc, Document)]), 'input should be either str, list or Document'
# --> 166         doc = self.process(doc)
#     167         return doc
#     168
#
# /usr/local/lib/python3.6/dist-packages/stanza/pipeline/core.py in process(self, doc)
#     158         for processor_name in PIPELINE_NAMES:
#     159             if self.processors.get(processor_name):
# --> 160                 doc = self.processors[processor_name].process(doc)
#     161         return doc
#     162
#
# /usr/local/lib/python3.6/dist-packages/stanza/pipeline/tokenize_processor.py in process(self, document)
#      86                                    self.config.get('max_seqlen', TokenizeProcessor.MAX_SEQ_LENGTH_DEFAULT),
#      87                                    orig_text=raw_text,
# ---> 88                                    no_ssplit=self.config.get('no_ssplit', False))
#      89         return doc.Document(document, raw_text)
#
# /usr/local/lib/python3.6/dist-packages/stanza/models/tokenize/utils.py in output_predictions(output_file, trainer, data_generator, vocab, mwt_dict, max_seqlen, orig_text, no_ssplit)
#      88         N = len(batch[3][0])
#      89         if N <= eval_limit:
# ---> 90             pred = np.argmax(trainer.predict(batch), axis=2)
#      91         else:
#      92             idx = [0] * len(batchparas)
#
# /usr/local/lib/python3.6/dist-packages/stanza/models/tokenize/trainer.py in predict(self, inputs)
#      65             features = features.cuda()
#      66
# ---> 67         pred = self.model(units, features)
#      68
#      69         return pred.data.cpu().numpy()
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/stanza/models/tokenize/model.py in forward(self, x, feats)
#      45         emb = torch.cat([emb, feats], 2)
#      46
# ---> 47         inp, _ = self.rnn(emb)
#      48
#      49         if self.args['conv_res'] is not None:
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     557         if batch_sizes is None:
#     558             result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# --> 559                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     560         else:
#     561             result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
#
# KeyboardInterrupt:

# %%
c
# Out:
# 266

# %%
c_title = 0
for ad in tqdm(ad_titles):
    ents = nlp(ad).entities
    for entity in ents:
        #print(type(entity))
        if entity.type == 'PERSON':
            print(ad, entity)
            c_title += 1
# Out:
# HBox(children=(FloatProgress(value=0.0, max=932888.0), HTML(value='')))
# Duo Available All night My loveOne of a Kind Wild,Petite&TightReal; C-Cup( . )( . )Round Ass OpenMind {
#   "text": "Petite&TightReal",
#   "type": "PERSON",
#   "start_char": 50,
#   "end_char": 66
# }
# 🍭ExØtic Pl@YMaTe🍭 【 💖δε∂υ©†¡√ε & N@ugh†y💖】 {
#   "text": "ExØtic Pl@YMa",
#   "type": "PERSON",
#   "start_char": 1,
#   "end_char": 14
# }
# 6475465111 RICHMOND HILL (NEW)  Today New Special  Best AAA+ Attendants  AQUA SPA (NEW) {
#   "text": "RICHMOND HILL",
#   "type": "PERSON",
#   "start_char": 11,
#   "end_char": 24
# }
# Private -  Nicole - I am waiting for you!  - 35 {
#   "text": "Nicole",
#   "type": "PERSON",
#   "start_char": 11,
#   "end_char": 17
# }
# Kelly   Car Calls {
#   "text": "Kelly   Car Calls",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 17
# }
# Miss Claudia.. March special! {
#   "text": "Claudia",
#   "type": "PERSON",
#   "start_char": 5,
#   "end_char": 12
# }
# 5 Days Left For Carnal Delights With Your Ineffable Inamorata: Kate von Katz! $200/hr $150/hh {
#   "text": "Kate von Katz",
#   "type": "PERSON",
#   "start_char": 63,
#   "end_char": 76
# }
# :*:*LaTiNa BeAuTy EaStEr SpEcIaL {
#   "text": "Ty EaStEr SpEcIaL",
#   "type": "PERSON",
#   "start_char": 15,
#   "end_char": 32
# }
# Hailey available NOW  Incall  and outcall all day all night249-359-7773 {
#   "text": "Hailey",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 6
# }
# Hr Special  STUNNING Blondie   Juicy Puss* {
#   "text": "Blondie   Juicy Puss",
#   "type": "PERSON",
#   "start_char": 21,
#   "end_char": 41
# }
# Upscale Jayden!   NEW TO YOUR CITY !! I Lve My Nipples Sucked!  (( S**W*E*E*T  C*A*R*A*M *E* L*!) {
#   "text": "Jayden",
#   "type": "PERSON",
#   "start_char": 8,
#   "end_char": 14
# }
# SExy elegant  Stephanie,  in/outcalls, $60. incall special today till 630 pm only {
#   "text": "Stephanie",
#   "type": "PERSON",
#   "start_char": 14,
#   "end_char": 23
# }
# Slimy sexy slim Sasha from the south {
#   "text": "Sasha",
#   "type": "PERSON",
#   "start_char": 16,
#   "end_char": 21
# }
# 6474884007!!Stifflers Mom  Ain't Got Anything on Me! ;) Upscale Hotel~King Suite Redhead CiaraRyan {
#   "text": "Mom  Ai",
#   "type": "PERSON",
#   "start_char": 22,
#   "end_char": 29
# }
# 6474884007!!Stifflers Mom  Ain't Got Anything on Me! ;) Upscale Hotel~King Suite Redhead CiaraRyan {
#   "text": "Redhead CiaraRyan",
#   "type": "PERSON",
#   "start_char": 81,
#   "end_char": 98
# }
# Busty BBW Babe! Available Now! {
#   "text": "Babe",
#   "type": "PERSON",
#   "start_char": 10,
#   "end_char": 14
# }
# Meeka 💋 FRISKY FRIDAYS !!! INCALLS at BANFF TRAIL 👅180/$/“ {
#   "text": "Meeka",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 5
# }
# Young && Beautiful {
#   "text": "Young && Beautiful",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 18
# }
# 💕💕💕💕❤️💕💕  Masha  ❤️ 514-664-5903 ❤️ Available now 💕💕❤️💕💕💕 {
#   "text": "Masha",
#   "type": "PERSON",
#   "start_char": 10,
#   "end_char": 15
# }
# BomshellKassy Time limitedCome try me {
#   "text": "Bomshell",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 8
# }
# BomshellKassy Time limitedCome try me {
#   "text": "Kassy Time",
#   "type": "PERSON",
#   "start_char": 8,
#   "end_char": 18
# }
# MISSISSAUGA  Amazing Services   6478855339 {
#   "text": "MISSISSAUGA",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 11
# }
# Booty Play OutcallsA Lady Of Class Sexy Spinner Barbie {
#   "text": "Barbie",
#   "type": "PERSON",
#   "start_char": 48,
#   "end_char": 54
# }
# Freaky & Horny 💖🌹💖🌹💖🌹💖 OPENMINDED & ALL MENUS💖🌹💖🌹💖🌹💖 Rachel ⭐️🌅⭐️🌅⭐️🌅 Non-Rush VIP Services 💖🌹💖🌹💖🌹💖🌹💖🌹 {
#   "text": "Rachel",
#   "type": "PERSON",
#   "start_char": 53,
#   "end_char": 59
# }
# FOR The Mature Gentleman!  A TRULY * CLASSY * CLEAN * KIND * HONEST * SAFE LADY! 60 minimum {
#   "text": "The Mature Gentleman",
#   "type": "PERSON",
#   "start_char": 4,
#   "end_char": 24
# }
# 2 DAYS ONLY.       Princess Laura {
#   "text": "Laura",
#   "type": "PERSON",
#   "start_char": 28,
#   "end_char": 33
# }
# Zoey Minxs {
#   "text": "Zoey Minxs",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 10
# }
# BARBIE pary party party {
#   "text": "BARBIE",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 6
# }
# ______  L.I.C.K. My  & make me SQUIRTTTT   VOLUPTIOUS Ebony Vixen {
#   "text": "Ebony Vixen",
#   "type": "PERSON",
#   "start_char": 54,
#   "end_char": 65
# }
# StrongBlonde FrenchBig titts DDDIncall and Outcall {
#   "text": "StrongBlonde French",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 19
# }
# StrongBlonde FrenchBig titts DDDIncall and Outcall {
#   "text": "DDDIncall",
#   "type": "PERSON",
#   "start_char": 29,
#   "end_char": 38
# }
# StrongBlonde FrenchBig titts DDDIncall and Outcall {
#   "text": "Outcall",
#   "type": "PERSON",
#   "start_char": 43,
#   "end_char": 50
# }
# Chocolate Treat ..... Amy {
#   "text": "Amy",
#   "type": "PERSON",
#   "start_char": 22,
#   "end_char": 25
# }
# NEW PICS PRIVATE BUNGALOW  www.rockinrobin2015.com 416-660-8466  discrete clean & cozy!  CANADIAN  SWEETHEART Dvp/401 Victoria Park {
#   "text": "Victoria",
#   "type": "PERSON",
#   "start_char": 118,
#   "end_char": 126
# }
# Fluffy Toya*** Come play with me {
#   "text": "Fluffy Toya",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 11
# }
# Gina incall ! {
#   "text": "Gina",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 4
# }
# Caitlin  Specials A L L night LoNG Everything you need  European F E T I S H E S {
#   "text": "Caitlin  Specials",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 17
# }
# CHARLIE-D💋the totally SUBMISSIVE-BBW good girl👅who LIVES to please💦NOT🚗MOBILE➕NO🚫BB {
#   "text": "CHARLIE-D💋the",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 13
# }
# Frankie  Busty  Beautiful  6139813476  - OTTAWA {
#   "text": "Frankie  Busty",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 14
# }
# 1more client Amazing Reviews on SP411MIXED GODDESS THAI and FRENCH Gia Anderson {
#   "text": "Gia Anderson",
#   "type": "PERSON",
#   "start_char": 67,
#   "end_char": 79
# }
# Guaranteed Real Pics!  Crystal, Veronica, April  Niagarase.ca  905-935-0040 {
#   "text": "Veronica",
#   "type": "PERSON",
#   "start_char": 32,
#   "end_char": 40
# }
# 647-710-4077 Meghan 38ddds Natural GORGEOUS FACE...Love to kiss & cuddle!Oshawa Wednesday {
#   "text": "Meghan",
#   "type": "PERSON",
#   "start_char": 13,
#   "end_char": 19
# }
# limited time only  DO NOT MISS! Kathia xXxXx {
#   "text": "Kathia xXxXx",
#   "type": "PERSON",
#   "start_char": 32,
#   "end_char": 44
# }
# FREAKY SATURDAY BombShell KAYLA PERFECTB & Sweet & Juicy {
#   "text": "BombShell",
#   "type": "PERSON",
#   "start_char": 16,
#   "end_char": 25
# }
# Independent HIGH class Girlfriend Experien*ce  is now  AVAILABLE  in Calgary ME {
#   "text": "Experien*ce",
#   "type": "PERSON",
#   "start_char": 34,
#   "end_char": 45
# }
# Amazing Emily 647-491-6755  Skype Show and Premium Snapchat  only Outcall  - 24 {
#   "text": "Emily",
#   "type": "PERSON",
#   "start_char": 8,
#   "end_char": 13
# }
# MATURE Caucasian Gentlemen 35+.. {
#   "text": "MATURE",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 6
# }
# Tinna Party girlDominican&Jamaican; 5 star girl  Massage included  Ebony New in town {
#   "text": "Ebony New",
#   "type": "PERSON",
#   "start_char": 67,
#   "end_char": 76
# }
# OUTCALL/INCALL private Condo Horny Bunny For serious ManBlack Doll {
#   "text": "Condo Horny Bunny",
#   "type": "PERSON",
#   "start_char": 23,
#   "end_char": 40
# }
# OUTCALL/INCALL private Condo Horny Bunny For serious ManBlack Doll {
#   "text": "ManBlack Doll",
#   "type": "PERSON",
#   "start_char": 53,
#   "end_char": 66
# }
# Seductive Cindy experienced!!! {
#   "text": "Cindy",
#   "type": "PERSON",
#   "start_char": 10,
#   "end_char": 15
# }
# Skype shows only !! Scotian cutie {
#   "text": "Scotian",
#   "type": "PERSON",
#   "start_char": 20,
#   "end_char": 27
# }
# Brittany banx! Come and get it! 😘 {
#   "text": "Brittany",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 8
# }
# ~~~NOW  AVAILABLE ~~~ Allana ~ Heather ~ Clare ~ OPEN for business 4am till 11am {
#   "text": "Clare",
#   "type": "PERSON",
#   "start_char": 41,
#   "end_char": 46
# }
# curvy Kayla  Duos available {
#   "text": "Kayla",
#   "type": "PERSON",
#   "start_char": 6,
#   "end_char": 11
# }
# Ari Mississauga 2night  P/ G F E  SexyHot MamiBBW  G reekK sloppy Mouth O rally gifted {
#   "text": "Ari Mississauga",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 15
# }
# VANESSA Busty beauty 32DDs Incalls only {
#   "text": "VANESSA",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 7
# }
# Goodtime with Besttime Izzabella587-402-1995 {
#   "text": "Besttime Izzabella587-402-1995",
#   "type": "PERSON",
#   "start_char": 14,
#   "end_char": 44
# }
# SeXii "PERSIAN BOMBSHELL"   Downtown High End {
#   "text": "SeXii",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 5
# }
# Scarborough Only for a limited time!! BBW Spanish Native Mix Ayana {
#   "text": "Scarborough",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 11
# }
# Mistress Betty Rage 38DD total GODDESS {
#   "text": "Betty Rage",
#   "type": "PERSON",
#   "start_char": 9,
#   "end_char": 19
# }
# Kller dy , & kll Tht Wll Leve Yu Wntng re!  ll NOW {
#   "text": "Kller dy",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 8
# }
# Taylor Rose {
#   "text": "Taylor Rose",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 11
# }
# FELIZ AO 2018! Celebrate it with Penelope West {
#   "text": "Penelope West",
#   "type": "PERSON",
#   "start_char": 33,
#   "end_char": 46
# }
# OUTCALLONLY    ALT BLONDE   G_R_3_3_K FAVE   DADDY's Bad Girl {
#   "text": "Bad Girl",
#   "type": "PERSON",
#   "start_char": 53,
#   "end_char": 61
# }
# Kylie New video! Brazilian Stripper ( 80 SPECIAL ) - > NISKU / AIRPORT {
#   "text": "Kylie",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 5
# }
# Jessica Im Ur Dream Baby Come Taste Me  New In Town For 1 week 24H IN/OUT 587-782-8205 {
#   "text": "Jessica",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 7
# }
# SuPer FreAk!!! Hot SeXy MiXed CuTTee {
#   "text": "SuPer FreAk",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 11
# }
# New Gush*er The real deal Sq*uiRT*ER! Now available! {
#   "text": "New Gush*er",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 11
# }
# Hottest ebony model in Hamilton!  Smokeshow ~FELICIA~ book the BEST book with PMC! {
#   "text": "FELICIA",
#   "type": "PERSON",
#   "start_char": 45,
#   "end_char": 52
# }
# Jamacian BAE Ebony College BAE! Brampton Beauty  Outcalls with a TRUE GEM let's PLAY {
#   "text": "Jamacian BAE",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 12
# }
# Jamacian BAE Ebony College BAE! Brampton Beauty  Outcalls with a TRUE GEM let's PLAY {
#   "text": "Brampton Beauty",
#   "type": "PERSON",
#   "start_char": 32,
#   "end_char": 47
# }
# Sexy Beebaby ;) Dark Hair. Blue Eyes. Killing Body ;) Available To Play Now!! {
#   "text": "Dark Hair.",
#   "type": "PERSON",
#   "start_char": 16,
#   "end_char": 26
# }
# Party Girl❤️❤️Ebony Barbie❤️❤️❤️❤️ {
#   "text": "Ebony Barbie❤️❤️❤️❤️",
#   "type": "PERSON",
#   "start_char": 14,
#   "end_char": 34
# }
# Pornstar  Material, im Horn Ee...  I make it    Sexy Harmony  Tease  587 404 7735. {
#   "text": "Horn Ee",
#   "type": "PERSON",
#   "start_char": 23,
#   "end_char": 30
# }
# Vixen Victoria Spanish Saucey Spinner in Thornhill {
#   "text": "Vixen Victoria",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 14
# }
# Vixen Victoria Spanish Saucey Spinner in Thornhill {
#   "text": "Saucey Spinner",
#   "type": "PERSON",
#   "start_char": 23,
#   "end_char": 37
# }
# Exotic Ebony Maya  INCALLS/OUTCALLS ALL NIGHT BABY Im Ready to please you Papi {
#   "text": "Exotic Ebony",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 12
# }
# Exotic Ebony Maya  INCALLS/OUTCALLS ALL NIGHT BABY Im Ready to please you Papi {
#   "text": "Maya",
#   "type": "PERSON",
#   "start_char": 13,
#   "end_char": 17
# }
# Exotic Ebony Maya  INCALLS/OUTCALLS ALL NIGHT BABY Im Ready to please you Papi {
#   "text": "Papi",
#   "type": "PERSON",
#   "start_char": 74,
#   "end_char": 78
# }
# Ms.Madison  Has got that Fine, Fresh, Fierce Friday special for you CALL RIGHT MEOW !!!!! {
#   "text": "Madison",
#   "type": "PERSON",
#   "start_char": 3,
#   "end_char": 10
# }
# Orillia Incall outcall Now  - till late    Incall &Outcall; Hailey   249-359-7773. {
#   "text": "Orillia Incall",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 14
# }
# Irina Diamond  LAST NIGHT  MUTH WET   PUSSY HOT  Back by popular demand for the weekend {
#   "text": "Irina Diamond",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 13
# }
# Scratch Shannon off your Saturday To-Do List 905-531-8764. Chubby Chasers Only! {
#   "text": "Scratch Shannon",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 15
# }
# Naughty Anastasia {
#   "text": "Naughty Anastasia",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 17
# }
# East Klassy Karie incalls or outcalls,613-619-7955 east {
#   "text": "Karie",
#   "type": "PERSON",
#   "start_char": 12,
#   "end_char": 17
# }
# Hey it's Rachel serious men only don't waste my time {
#   "text": "Rachel",
#   "type": "PERSON",
#   "start_char": 9,
#   "end_char": 15
# }
# -:- $100 Special!- Exotic Maliah  -:- {
#   "text": "Maliah",
#   "type": "PERSON",
#   "start_char": 26,
#   "end_char": 32
# }
# HAIRY  !Hairy Puss* cat come  play :)) {
#   "text": "Hairy Puss",
#   "type": "PERSON",
#   "start_char": 8,
#   "end_char": 18
# }
# Nawty Nikkeh  Never Rush OpenMinded  Dwn 4 w.e {
#   "text": "Nawty Nikkeh",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 12
# }
# Cassandre! last chance last!!Last day working {
#   "text": "Cassandre",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 9
# }
# Indian Punjabi * blond Layla * Eropean nna* Spanish Christina*hirriing 9054573756 {
#   "text": "Layla",
#   "type": "PERSON",
#   "start_char": 23,
#   "end_char": 28
# }
# Perle Rare  Natural Curves  Amazing Big Booty  Real pics {
#   "text": "Perle Rare",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 10
# }
# Alexandra, Smoking Hot Sexy Blonde {
#   "text": "Alexandra",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 9
# }
# Gorgeous  ELIZABETH  available 24/7 In/Out in Toronto {
#   "text": "Gorgeous  ELIZABETH",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 19
# }
# ####____3 sexy Asian girls -Coco -Emily --Yoyo-_#####--100$ all included special service --Must try {
#   "text": "Coco -Emily",
#   "type": "PERSON",
#   "start_char": 28,
#   "end_char": 39
# }
# ####____3 sexy Asian girls -Coco -Emily --Yoyo-_#####--100$ all included special service --Must try {
#   "text": "--Yoyo-_#####--100$",
#   "type": "PERSON",
#   "start_char": 40,
#   "end_char": 59
# }
# Mary! {
#   "text": "Mary",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 4
# }
# Fit East  Coaster small Nikki {
#   "text": "Nikki",
#   "type": "PERSON",
#   "start_char": 24,
#   "end_char": 29
# }
# 416-726-8032SexXy RussIan Ariana MORNING SPECIALS  p@rty Girl {
#   "text": "SexXy RussIan Ariana",
#   "type": "PERSON",
#   "start_char": 12,
#   "end_char": 32
# }
# Aleisha {
#   "text": "Aleisha",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 7
# }
# EbonyDominicainCurvy& Busty  How wide can my   Open ? Tight GripAvailable Now 587-408-7092 {
#   "text": "EbonyDominicain",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 15
# }
# EbonyDominicainCurvy& Busty  How wide can my   Open ? Tight GripAvailable Now 587-408-7092 {
#   "text": "Curvy& Busty",
#   "type": "PERSON",
#   "start_char": 15,
#   "end_char": 27
# }
# Ready NowNAUGHTY  NIKKI {
#   "text": "Ready Now",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 9
# }
# The PERFECT EBONY Barbie  Guranteed Good time {
#   "text": "Barbie  Guranteed",
#   "type": "PERSON",
#   "start_char": 18,
#   "end_char": 35
# }
# CAMBRIDG LAST 2DAYS PETITE SLIM LOVELY  PRETTY  ASIAN DOLL {
#   "text": "CAMBRIDG",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 8
# }
# Sexii Sam ... xox NEW PICS {
#   "text": "Sexii Sam",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 9
# }
# ❤Mature☆Sweet Chocolate♡☆Ebony Vixen♡Lexus☆ ☎ (587-3360347)☎ Sherwood park {
#   "text": "Ebony Vixen",
#   "type": "PERSON",
#   "start_char": 25,
#   "end_char": 36
# }
# Princess Leah ,  OUTCALLS ONLY   .....  Providing Royalty Treatment {
#   "text": "Leah",
#   "type": "PERSON",
#   "start_char": 9,
#   "end_char": 13
# }
# (26) Im Mary the only girl worth your precious time... MP {
#   "text": "Mary",
#   "type": "PERSON",
#   "start_char": 8,
#   "end_char": 12
# }
# *Last Day* [Downtown] Crme De La Crme {
#   "text": "Crme De La Crme",
#   "type": "PERSON",
#   "start_char": 22,
#   "end_char": 37
# }
# --------  Vicky      Busty      Hot   Blonde    Like    to    Play    -------------- {
#   "text": "Vicky      Busty",
#   "type": "PERSON",
#   "start_char": 10,
#   "end_char": 26
# }
# Outcalls!   _ Blonde tanned Bombshell {
#   "text": "Bombshell",
#   "type": "PERSON",
#   "start_char": 28,
#   "end_char": 37
# }
# Vaughan ❇️‼️❤️⭐️ Real Photos AND Great Services ❤️‼️❇️ #1 Miss Meghan {
#   "text": "Vaughan",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 7
# }
# Vaughan ❇️‼️❤️⭐️ Real Photos AND Great Services ❤️‼️❇️ #1 Miss Meghan {
#   "text": "Meghan",
#   "type": "PERSON",
#   "start_char": 63,
#   "end_char": 69
# }
# Man2man Toronto etobicoke.   Full body erotic relaxing massage.text only 2897690284 {
#   "text": "Man2man Toronto",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 15
# }
# VERY Beautiful Jessica  TOP Quality Outcall  Long Lasting Pleasure  100% Real Pic~ {
#   "text": "Jessica  TOP",
#   "type": "PERSON",
#   "start_char": 15,
#   "end_char": 27
# }
# Start your day right, with me  Kenzi 4039695741 {
#   "text": "Kenzi",
#   "type": "PERSON",
#   "start_char": 31,
#   "end_char": 36
# }
# 3 BLONDE GIRLS  ... Princess Leah  & Alyssa Royalty  , & CassieXo  ---- GUELPH INCALLS {
#   "text": "Leah",
#   "type": "PERSON",
#   "start_char": 29,
#   "end_char": 33
# }
# 3 BLONDE GIRLS  ... Princess Leah  & Alyssa Royalty  , & CassieXo  ---- GUELPH INCALLS {
#   "text": "Alyssa Royalty",
#   "type": "PERSON",
#   "start_char": 37,
#   "end_char": 51
# }
# NEWKATIE   Sexy, Curvy and Tall {
#   "text": "NEWKATIE",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 8
# }
# NEWKATIE   Sexy, Curvy and Tall {
#   "text": "Tall",
#   "type": "PERSON",
#   "start_char": 27,
#   "end_char": 31
# }
# New Korea  Tiny Jina -   Your Little happy Secret  Speak fluent English {
#   "text": "Tiny Jina",
#   "type": "PERSON",
#   "start_char": 11,
#   "end_char": 20
# }
# 120 h/h Best Super Soaker At Your Service! Sqqqquirter Chocolatey Goodness Boobs&Booty; {
#   "text": "Sqqqquirter Chocolatey Goodness Boobs&Booty",
#   "type": "PERSON",
#   "start_char": 43,
#   "end_char": 86
# }
# LAST Day!!! Chocolate Princess GIA  Well Reviewed on CAF!!!  Dec 2nd BOOK Now {
#   "text": "Princess GIA",
#   "type": "PERSON",
#   "start_char": 22,
#   "end_char": 34
# }
# Hottestonduo 1st night togetherwhat kind of Trouble can we get into? {
#   "text": "Hottestonduo",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 12
# }
# Mary PoppINS💦💦💋💋💋 {
#   "text": "Mary PoppINS💦💦💋💋💋",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 17
# }
# BEST relaxing bodywork 604-746-6777 Judy {
#   "text": "Judy",
#   "type": "PERSON",
#   "start_char": 36,
#   "end_char": 40
# }
# Jasmine -sweet-Latina {
#   "text": "Jasmine -sweet-Latina",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 21
# }
# Last tourMelissa:-*LOOKS GOOD FEELS  EVEN  BETTER PLeaSurEs PLaYgRouND* - {
#   "text": "Melissa",
#   "type": "PERSON",
#   "start_char": 9,
#   "end_char": 16
# }
# Sexy TransexualTS Angeliya Rose in town now 3-9 Nov Only,  First Timer Most Welcome ;-) {
#   "text": "Angeliya",
#   "type": "PERSON",
#   "start_char": 18,
#   "end_char": 26
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-05f8b0861566> in <module>
#       1 c_title = 0
#       2 for ad in tqdm(ad_titles):
# ----> 3     ents = nlp(ad).entities
#       4     for entity in ents:
#       5         #print(type(entity))
#
# /usr/local/lib/python3.6/dist-packages/stanza/pipeline/core.py in __call__(self, doc)
#     164         assert any([isinstance(doc, str), isinstance(doc, list),
#     165                     isinstance(doc, Document)]), 'input should be either str, list or Document'
# --> 166         doc = self.process(doc)
#     167         return doc
#     168
#
# /usr/local/lib/python3.6/dist-packages/stanza/pipeline/core.py in process(self, doc)
#     158         for processor_name in PIPELINE_NAMES:
#     159             if self.processors.get(processor_name):
# --> 160                 doc = self.processors[processor_name].process(doc)
#     161         return doc
#     162
#
# /usr/local/lib/python3.6/dist-packages/stanza/pipeline/depparse_processor.py in process(self, document)
#      40         preds = []
#      41         for i, b in enumerate(batch):
# ---> 42             preds += self.trainer.predict(b)
#      43         if batch.data_orig_idx is not None:
#      44             preds = unsort(preds, batch.data_orig_idx)
#
# /usr/local/lib/python3.6/dist-packages/stanza/models/depparse/trainer.py in predict(self, batch, unsort)
#      72         self.model.eval()
#      73         batch_size = word.size(0)
# ---> 74         _, preds = self.model(word, word_mask, wordchars, wordchars_mask, upos, xpos, ufeats, pretrained, lemma, head, deprel, word_orig_idx, sentlens, wordlens)
#      75         head_seqs = [chuliu_edmonds_one_root(adj[:l, :l])[1:] for adj, l in zip(preds[0], sentlens)] # remove attachment for the root
#      76         deprel_seqs = [self.vocab['deprel'].unmap([preds[1][i][j+1][h] for j, h in enumerate(hs)]) for i, hs in enumerate(head_seqs)]
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/stanza/models/depparse/model.py in forward(self, word, word_mask, wordchars, wordchars_mask, upos, xpos, ufeats, pretrained, lemma, head, deprel, word_orig_idx, sentlens, wordlens)
#     131         lstm_inputs = PackedSequence(lstm_inputs, inputs[0].batch_sizes)
#     132
# --> 133         lstm_outputs, _ = self.parserlstm(lstm_inputs, sentlens, hx=(self.parserlstm_h_init.expand(2 * self.args['num_layers'], word.size(0), self.args['hidden_dim']).contiguous(), self.parserlstm_c_init.expand(2 * self.args['num_layers'], word.size(0), self.args['hidden_dim']).contiguous()))
#     134         lstm_outputs, _ = pad_packed_sequence(lstm_outputs, batch_first=True)
#     135
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/stanza/models/common/hlstm.py in forward(self, input, seqlens, hx)
#     107             cs.append(ct)
#     108
# --> 109             input = PackedSequence(h.data + torch.sigmoid(self.gate[l](input.data)) * highway_func(self.highway[l](input.data)), input.batch_sizes)
#     110
#     111         if self.pad:
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1368     if input.dim() == 2 and bias is not None:
#    1369         # fused op is marginally faster
# -> 1370         ret = torch.addmm(bias, input, weight.t())
#    1371     else:
#    1372         output = input.matmul(weight.t())
#
# KeyboardInterrupt:

# %%
c_title
# Out:
# 131

# %%
c_title_lower = 0
for ad in tqdm(ad_titles):
    ents = nlp(ad.lower()).entities
    for entity in ents:
        #print(type(entity))
        if entity.type == 'PERSON':
            print(ad, entity)
            c_title_lower += 1
# Out:
# HBox(children=(FloatProgress(value=0.0, max=932888.0), HTML(value='')))
# 2 DAYS ONLY.       Princess Laura {
#   "text": "laura",
#   "type": "PERSON",
#   "start_char": 28,
#   "end_char": 33
# }
# CHARLIE-D💋the totally SUBMISSIVE-BBW good girl👅who LIVES to please💦NOT🚗MOBILE➕NO🚫BB {
#   "text": "charlie-d💋",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 10
# }
# Seductive Cindy experienced!!! {
#   "text": "cindy",
#   "type": "PERSON",
#   "start_char": 10,
#   "end_char": 15
# }
# Kylie New video! Brazilian Stripper ( 80 SPECIAL ) - > NISKU / AIRPORT {
#   "text": "kylie",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 5
# }
# Hottest ebony model in Hamilton!  Smokeshow ~FELICIA~ book the BEST book with PMC! {
#   "text": "felicia",
#   "type": "PERSON",
#   "start_char": 45,
#   "end_char": 52
# }
# BREE'S BACK..JULY 15TH & 16TH ONLY {
#   "text": "bree",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 4
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-7896dc5b60b7> in <module>
#       1 c_title_lower = 0
#       2 for ad in tqdm(ad_titles):
# ----> 3     ents = nlp(ad.lower()).entities
#       4     for entity in ents:
#       5         #print(type(entity))
#
# /usr/local/lib/python3.6/dist-packages/stanza/pipeline/core.py in __call__(self, doc)
#     164         assert any([isinstance(doc, str), isinstance(doc, list),
#     165                     isinstance(doc, Document)]), 'input should be either str, list or Document'
# --> 166         doc = self.process(doc)
#     167         return doc
#     168
#
# /usr/local/lib/python3.6/dist-packages/stanza/pipeline/core.py in process(self, doc)
#     158         for processor_name in PIPELINE_NAMES:
#     159             if self.processors.get(processor_name):
# --> 160                 doc = self.processors[processor_name].process(doc)
#     161         return doc
#     162
#
# /usr/local/lib/python3.6/dist-packages/stanza/pipeline/sentiment_processor.py in process(self, document)
#      38         sentences = document.sentences
#      39         text = [" ".join(token.text for token in sentence.tokens) for sentence in sentences]
# ---> 40         labels = cnn_classifier.label_text(self._model, text, batch_size=self._batch_size)
#      41         # TODO: allow a classifier processor for any attribute, not just sentiment
#      42         document.set(SENTIMENT, labels, to_sentence=True)
#
# /usr/local/lib/python3.6/dist-packages/stanza/models/classifiers/cnn_classifier.py in label_text(model, text, batch_size, reverse_label_map, device)
#     337     labels = []
#     338     for interval in intervals:
# --> 339         output = model(text[interval[0]:interval[1]], device)
#     340         predicted = torch.argmax(output, dim=1)
#     341         labels.extend(predicted.tolist())
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/stanza/models/classifiers/cnn_classifier.py in forward(self, inputs, device)
#     214         if self.extra_vocab:
#     215             extra_batch_indices = torch.tensor(extra_batch_indices, requires_grad=False, device=device)
# --> 216             extra_input_vectors = self.extra_embedding(extra_batch_indices)
#     217             if self.config.extra_wordvec_method is classifier_args.ExtraVectors.CONCAT:
#     218                 input_vectors = torch.cat([input_vectors, extra_input_vectors], dim=2)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/sparse.py in forward(self, input)
#     112         return F.embedding(
#     113             input, self.weight, self.padding_idx, self.max_norm,
# --> 114             self.norm_type, self.scale_grad_by_freq, self.sparse)
#     115
#     116     def extra_repr(self):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    1482         # remove once script supports set_grad_enabled
#    1483         _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 1484     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#    1485
#    1486
#
# KeyboardInterrupt:

# %%
c_title_lower
# Out:
# 6

# %%
sampled_data = pd.concat([data[data.label==1].sample(n=500), data[data.label==0].sample(n=500)])

# %%
sampled_data = sampled_data.sample(frac=1)

# %%
def get_ngrams(text):
    tokens = word_tokenize(text)
    tokensProcessed = [token.lower() for token in tokens if token not in stopwords.words('english')]
    bigrams = list(ngrams(tokensProcessed, 2))
    unigrams = list(ngrams(tokensProcessed, 1))
    return unigrams, bigrams

# %%
def get_loc_features(text):
    vectorizer = CountVectorizer(tokenizer=word_tokenize, stop_words=stopwords.words('english'), ngram_range=(1,1))
    features = vectorizer.fit_transform(text)
    return features.toarray(), vectorizer.get_feature_names()

# %%
def get_features(text):
    vectorizer_uni = CountVectorizer(tokenizer=word_tokenize, stop_words=stopwords.words('english'), ngram_range=(1,1))
    features_uni = vectorizer_uni.fit_transform(text)
    vectorizer_bi = CountVectorizer(tokenizer=word_tokenize, stop_words=stopwords.words('english'), ngram_range=(2,2))
    features_bi = vectorizer_bi.fit_transform(text)
    return features_uni.toarray(), vectorizer_uni.get_feature_names(), features_bi.toarray(), vectorizer_bi.get_feature_names()

# %%
desc_features_uni, desc_feature_names_uni, desc_features_bi, desc_feature_names_bi = get_features(sampled_data.u_Description)
title_features_uni, title_feature_names_uni, title_features_bi, title_feature_names_bi = get_features(sampled_data.u_Title)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py:386: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ["'d", "'ll", "'re", "'s", "'ve", 'could', 'might', 'must', "n't", 'need', 'sha', 'wo', 'would'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
loc_features, loc_feature_names = get_loc_features(sampled_data.u_Location)

# %%
sum(desc_features_bi[839])+sum(title_features_bi[839])
# Out:
# 45

# %%
title_features_uni.shape
# Out:
# (1000, 3073)

# %%
feature_vectors = np.concatenate((desc_features_uni, title_features_uni, desc_features_bi, title_features_bi, title_features_bi), axis=1)

# %%
feature_vectors.shape
# Out:
# (1000, 55523)

# %%
sampled_data_labels = sampled_data.label.values

# %%
pkl.dump(sampled_data_labels, open("data/sample_data/sampled_data_labels.pkl","wb"))
pkl.dump(feature_vectors, open("data/sample_data/sampled_data_features.pkl","wb"), protocol=4)

# %%
feature_names = np.append(np.append(np.append(np.append(desc_feature_names_uni, desc_feature_names_bi), title_feature_names_uni), title_feature_names_bi), loc_feature_names)

# %%
pkl.dump(feature_names, open("data/sample_data/sampled_data_feature_names.pkl","wb"), protocol=4)

# %%
feature_names = list(set(np.concatenate([desc_feature_names_uni, desc_feature_names_bi, title_feature_names_uni, title_feature_names_bi, loc_feature_names])))

# %%
# mapping feature words to ids
word_to_id_map = {}
counter = 1
for word in tqdm(set(feature_names)):
    word_to_id_map[word] = -counter
    counter += 1
# Out:
# HBox(children=(FloatProgress(value=0.0, max=46248.0), HTML(value='')))

# %%
desc_feature_names_uni_values = []
for word in set(desc_feature_names_uni):
    desc_feature_names_uni_values.append(word_to_id_map[word])

desc_feature_names_bi_values = []
for word in set(desc_feature_names_bi):
    desc_feature_names_bi_values.append(word_to_id_map[word])
    
title_feature_names_uni_values = []
for word in set(title_feature_names_uni):
    title_feature_names_uni_values.append(word_to_id_map[word])
    
title_feature_names_bi_values = []
for word in set(title_feature_names_bi):
    title_feature_names_bi_values.append(word_to_id_map[word])
    
loc_feature_names_values = []
for word in set(loc_feature_names):
    loc_feature_names_values.append(word_to_id_map[word])

# %%
pkl.dump(desc_feature_names_uni_values, open("data/sample_data/desc_feature_names_uni.pkl","wb"))
pkl.dump(desc_feature_names_bi_values, open("data/sample_data/desc_feature_names_bi.pkl","wb"))
pkl.dump(title_feature_names_uni_values, open("data/sample_data/title_feature_names_uni.pkl","wb"))
pkl.dump(title_feature_names_bi_values, open("data/sample_data/title_feature_names_bi.pkl","wb"))
pkl.dump(loc_feature_names_values, open("data/sample_data/loc_feature_names.pkl","wb"))

# %%
pkl.dump(word_to_id_map, open("data/sample_data/feature_name_to_id_map.pkl","wb"))

# %% [markdown]
# ## Discogs data

# %%
# This data file path needs to be set accordingly
gt = pd.read_csv("data/discogs/groundTruthNodeLabels.csv")
gt.head()
# Out:
#     MastRel1      ArtID1
# 0   MastRel1  ExArtID239
# 1  MastRel14     ArtID50
# 2  MastRel14   ExArtID26
# 3  MastRel14  ExArtID239
# 4  MastRel15     ArtID51

# %%
attr = pd.read_csv("data/discogs/nodeAttributeFile.csv")
attr.head()
# Out:
#                       TRACKмой_новый_мир  TRAC
# 0  TRACKhang_four_xaver_von_treyer_remix  TRAC
# 1                         MastRel1790126  Mast
# 2                 TRACKmona_lise_version  TRAC
# 3                         MastRel1790129  Mast
# 4      TRACKbailamos_mijangos_remix_edit  TRAC

# %% [markdown]
# ## Synthetic Data

# %%
# This data file path needs to be set accordingly
synthetic_data_1 = pd.read_csv("data/Synthetic data/star_5000_100_1.0.csv").set_index('index')
synthetic_data_1.head()
# Out:
#        Unnamed: 0  Unnamed: 0.1  \
# index
# 0.0             0           0.0
# 1.0             1           1.0
# 2.0             2           2.0
# 3.0             3           3.0
# 4.0             4           4.0
#
#                                                      url  \
# index
# 0.0        https://hard.com/rat/evis/pre/198.to-evers-of
# 1.0           http://as.fr/thas/Souses/catemb/Decien.jpg
# 2.0    http://arito.com/pionfe/whical/groper.ands-per...
# 3.0                             http://Bution489.org.jsp
# 4.0                                   https://for.ru.php
#
#                                              description         phone  \
# index
# 0.0    And security, as intelligent and severe, and b...  984-587-0387
# 1.0    Many applications be "harsh, sometimes. Diphth...  634-845-6692
# 2.0    Of fur, saturday, or maybe only a. All sorts u...  936-592-2277
# 3.0    Just one when organisms die, carbon is. Hopes ...  614-674-5648
# 4.0    Seattle polish minister nabil el-araby. the ar...  393-340-1264
#
#       row_type  label
# index
# 0.0     source      0
# 1.0     source      1
# 2.0     source      2
# 3.0     source      3
# 4.0     source      4
